# %%
import datetime


#load file 
from email import message_from_file
import os
import email
# Path to directory where attachments will be stored:
path = "./msgfiles"

# To have attachments extracted into memory, change behaviour of 2 following functions:

def file_exists (f):
    """Checks whether extracted file was extracted before."""
    return os.path.exists(os.path.join(path, f))

def save_file (fn, cont):
    """Saves cont to a file fn"""
    file = open(os.path.join(path, fn), "wb")
    file.write(cont)
    file.close()

def construct_name (id, fn):
    """Constructs a file name out of messages ID and packed file name"""
    id = id.split(".")
    id = id[0]+id[1]
    return id+"."+fn

def disqo (s):
    """Removes double or single quotations."""
    s = s.strip()
    if s.startswith("'") and s.endswith("'"): return s[1:-1]
    if s.startswith('"') and s.endswith('"'): return s[1:-1]
    return s

def disgra (s):
    """Removes < and > from HTML-like tag or e-mail address or e-mail ID."""
    s = s.strip()
    if s.startswith("<") and s.endswith(">"): return s[1:-1]
    return s

def pullout (m, key):
    """Extracts content from an e-mail message.
    This works for multipart and nested multipart messages too.
    m   -- email.Message() or mailbox.Message()
    key -- Initial message ID (some string)
    Returns tuple(Text, Html, Files, Parts)
    Text  -- All text from all parts.
    Html  -- All HTMLs from all parts
    Files -- Dictionary mapping extracted file to message ID it belongs to.
    Parts -- Number of parts in original message.
    """
    Html = ""
    Text = ""
    Files = {}
    Parts = 0
    if not m.is_multipart():
        if m.get_filename(): # It's an attachment
            fn = m.get_filename()
            cfn = construct_name(key, fn)
            Files[fn] = (cfn, None)
            if file_exists(cfn): return Text, Html, Files, 1
            return Text, Html, Files, 1
        # Not an attachment!
        # See where this belongs. Text, Html or some other data:
        cp = m.get_content_type()
        print(Html)
        if cp=="text/plain": Text += str(m.get_payload(decode=True))
        elif cp=="text/html": Html += str(m.get_payload(decode=True))
        else:
            # Something else!
            # Extract a message ID and a file name if there is one:
            # This is some packed file and name is contained in content-type header
            # instead of content-disposition header explicitly
            cp = m.get("content-type")
            try: id = disgra(m.get("content-id"))
            except: id = None
            # Find file name:
            o = cp.find("name=")
            if o==-1: return Text, Html, Files, 1
            ox = cp.find(";", o)
            if ox==-1: ox = None
            o += 5; fn = cp[o:ox]
            fn = disqo(fn)
            cfn = construct_name(key, fn)
            Files[fn] = (cfn, id)
            if file_exists(cfn): return Text, Html, Files, 1
            save_file(cfn, m.get_payload(decode=True))
        return Text, Html, Files, 1
    # This IS a multipart message.
    # So, we iterate over it and call pullout() recursively for each part.
    y = 0
    while 1:
        # If we cannot get the payload, it means we hit the end:
        try:
            pl = m.get_payload(y)
        except: break
        # pl is a new Message object which goes back to pullout
        t, h, f, p = pullout(pl, key)
        Text += t; Html += h; Files.update(f); Parts += p
        y += 1
    return Text, Html, Files, Parts

def extract (msgfile, key):
    """Extracts all data from e-mail, including From, To, etc., and returns it as a dictionary.
    msgfile -- A file-like readable object
    key     -- Some ID string for that particular Message. Can be a file name or anything.
    Returns dict()
    Keys: from, to, subject, date, text, html, parts[, files]
    Key files will be present only when message contained binary files.
    For more see __doc__ for pullout() and caption() functions.
    """
    m = message_from_file(msgfile)
    From, To, Subject, Date = caption(m)
    Text, Html, Files, Parts = pullout(m, key)
    Text = Text.strip(); Html = Html.strip()
    msg = {"subject": Subject, "from": From, "to": To, "date": Date,
        "text": Text, "html": Html, "parts": Parts}
    return msg

def caption (origin):
    """Extracts: To, From, Subject and Date from email.Message() or mailbox.Message()
    origin -- Message() object
    Returns tuple(From, To, Subject, Date)
    If message doesn't contain one/more of them, the empty strings will be returned.
    """
    Date = ""
    if "Date" in origin.keys(): Date = origin["date"].strip()
    From = ""
    if "From" in origin.keys(): From = origin["from"].strip()
    To = ""
    if "To" in origin.keys(): To = origin["to"].strip()
    Subject = ""
    if "Subject" in origin.keys(): Subject = origin["subject"].strip()
    return From, To, Subject, Date
    
    
import os

path="phishingMails"
dir_list = os.listdir(path)
dir_list
# Out:
# ['1.eml',
#  '10.eml',
#  '100.eml',
#  '1000.eml',
#  '1001.eml',
#  '1002.eml',
#  '1003.eml',
#  '1004.eml',
#  '1005.eml',
#  '1006.eml',
#  '1007.eml',
#  '1008.eml',
#  '1009.eml',
#  '101.eml',
#  '1010.eml',
#  '1011.eml',
#  '1012.eml',
#  '1013.eml',
#  '1014.eml',
#  '1015.eml',
#  '1016.eml',
#  '1017.eml',
#  '1018.eml',
#  '1019.eml',
#  '102.eml',
#  '1020.eml',
#  '1021.eml',
#  '1022.eml',
#  '1023.eml',
#  '1024.eml',
#  '1025.eml',
#  '1026.eml',
#  '1027.eml',
#  '1028.eml',
#  '1029.eml',
#  '103.eml',
#  '1030.eml',
#  '1031.eml',
#  '1032.eml',
#  '1033.eml',
#  '1034.eml',
#  '1035.eml',
#  '1036.eml',
#  '1037.eml',
#  '1038.eml',
#  '1039.eml',
#  '104.eml',
#  '1040.eml',
#  '1041.eml',
#  '1042.eml',
#  '1043.eml',
#  '1044.eml',
#  '1045.eml',
#  '1046.eml',
#  '1047.eml',
#  '1048.eml',
#  '1049.eml',
#  '105.eml',
#  '1050.eml',
#  '1051.eml',
#  '1052.eml',
#  '1053.eml',
#  '1054.eml',
#  '1055.eml',
#  '1056.eml',
#  '1057.eml',
#  '1058.eml',
#  '1059.eml',
#  '106.eml',
#  '1060.eml',
#  '1061.eml',
#  '1062.eml',
#  '1063.eml',
#  '1064.eml',
#  '1065.eml',
#  '1066.eml',
#  '1067.eml',
#  '1068.eml',
#  '1069.eml',
#  '107.eml',
#  '1070.eml',
#  '1071.eml',
#  '1072.eml',
#  '1073.eml',
#  '1074.eml',
#  '1075.eml',
#  '1076.eml',
#  '1077.eml',
#  '1078.eml',
#  '1079.eml',
#  '108.eml',
#  '1080.eml',
#  '1081.eml',
#  '1082.eml',
#  '1083.eml',
#  '1084.eml',
#  '1085.eml',
#  '1086.eml',
#  '1087.eml',
#  '1088.eml',
#  '1089.eml',
#  '109.eml',
#  '1090.eml',
#  '1091.eml',
#  '1092.eml',
#  '1093.eml',
#  '1094.eml',
#  '1095.eml',
#  '1096.eml',
#  '1097.eml',
#  '1098.eml',
#  '1099.eml',
#  '11.eml',
#  '110.eml',
#  '1100.eml',
#  '1101.eml',
#  '1102.eml',
#  '1103.eml',
#  '1104.eml',
#  '1105.eml',
#  '1106.eml',
#  '1107.eml',
#  '1108.eml',
#  '1109.eml',
#  '111.eml',
#  '1110.eml',
#  '1111.eml',
#  '1112.eml',
#  '1113.eml',
#  '1114.eml',
#  '1115.eml',
#  '1116.eml',
#  '1117.eml',
#  '1118.eml',
#  '1119.eml',
#  '112.eml',
#  '1120.eml',
#  '1121.eml',
#  '1122.eml',
#  '1123.eml',
#  '1124.eml',
#  '1125.eml',
#  '1126.eml',
#  '1127.eml',
#  '1128.eml',
#  '1129.eml',
#  '113.eml',
#  '1130.eml',
#  '1131.eml',
#  '1132.eml',
#  '1133.eml',
#  '1134.eml',
#  '1135.eml',
#  '1136.eml',
#  '1137.eml',
#  '1138.eml',
#  '1139.eml',
#  '114.eml',
#  '1140.eml',
#  '1141.eml',
#  '1142.eml',
#  '1143.eml',
#  '1144.eml',
#  '1145.eml',
#  '1146.eml',
#  '1147.eml',
#  '1148.eml',
#  '1149.eml',
#  '115.eml',
#  '1150.eml',
#  '1151.eml',
#  '1152.eml',
#  '1153.eml',
#  '1154.eml',
#  '1155.eml',
#  '1156.eml',
#  '1157.eml',
#  '1158.eml',
#  '1159.eml',
#  '116.eml',
#  '1160.eml',
#  '1161.eml',
#  '1162.eml',
#  '1163.eml',
#  '1164.eml',
#  '1165.eml',
#  '1166.eml',
#  '1167.eml',
#  '1168.eml',
#  '1169.eml',
#  '117.eml',
#  '1170.eml',
#  '1171.eml',
#  '1172.eml',
#  '1173.eml',
#  '1174.eml',
#  '1175.eml',
#  '1176.eml',
#  '1177.eml',
#  '1178.eml',
#  '1179.eml',
#  '118.eml',
#  '1180.eml',
#  '1181.eml',
#  '1182.eml',
#  '1183.eml',
#  '1184.eml',
#  '1185.eml',
#  '1186.eml',
#  '1187.eml',
#  '1188.eml',
#  '1189.eml',
#  '119.eml',
#  '1190.eml',
#  '1191.eml',
#  '1192.eml',
#  '1193.eml',
#  '1194.eml',
#  '1195.eml',
#  '1196.eml',
#  '1197.eml',
#  '1198.eml',
#  '1199.eml',
#  '12.eml',
#  '120.eml',
#  '1200.eml',
#  '1201.eml',
#  '1202.eml',
#  '1203.eml',
#  '1204.eml',
#  '1205.eml',
#  '1206.eml',
#  '1207.eml',
#  '1208.eml',
#  '1209.eml',
#  '121.eml',
#  '1210.eml',
#  '1211.eml',
#  '1212.eml',
#  '1213.eml',
#  '1214.eml',
#  '1215.eml',
#  '1216.eml',
#  '1217.eml',
#  '1218.eml',
#  '1219.eml',
#  '122.eml',
#  '1220.eml',
#  '1221.eml',
#  '1222.eml',
#  '1223.eml',
#  '1224.eml',
#  '1225.eml',
#  '1226.eml',
#  '1227.eml',
#  '1228.eml',
#  '1229.eml',
#  '123.eml',
#  '1230.eml',
#  '1231.eml',
#  '1232.eml',
#  '1233.eml',
#  '1234.eml',
#  '1235.eml',
#  '1236.eml',
#  '1237.eml',
#  '1238.eml',
#  '1239.eml',
#  '124.eml',
#  '1240.eml',
#  '1241.eml',
#  '1242.eml',
#  '1243.eml',
#  '1244.eml',
#  '1245.eml',
#  '1246.eml',
#  '1247.eml',
#  '1248.eml',
#  '1249.eml',
#  '125.eml',
#  '1250.eml',
#  '1252.eml',
#  '1254.eml',
#  '1255.eml',
#  '1256.eml',
#  '1257.eml',
#  '1258.eml',
#  '1259.eml',
#  '126.eml',
#  '1262.eml',
#  '1263.eml',
#  '1264.eml',
#  '1265.eml',
#  '1266.eml',
#  '1267.eml',
#  '1268.eml',
#  '1269.eml',
#  '127.eml',
#  '1270.eml',
#  '1271.eml',
#  '1272.eml',
#  '1273.eml',
#  '1274.eml',
#  '1275.eml',
#  '1276.eml',
#  '1277.eml',
#  '1278.eml',
#  '1279.eml',
#  '128.eml',
#  '1280.eml',
#  '1281.eml',
#  '1282.eml',
#  '1283.eml',
#  '1284.eml',
#  '1285.eml',
#  '1286.eml',
#  '1287.eml',
#  '1288.eml',
#  '1289.eml',
#  '1290.eml',
#  '1291.eml',
#  '1292.eml',
#  '1293.eml',
#  '1294.eml',
#  '1295.eml',
#  '1296.eml',
#  '1297.eml',
#  '1298.eml',
#  '1299.eml',
#  '13.eml',
#  '1300.eml',
#  '1301.eml',
#  '1302.eml',
#  '1303.eml',
#  '1304.eml',
#  '1305.eml',
#  '1306.eml',
#  '1307.eml',
#  '1308.eml',
#  '1309.eml',
#  '131.eml',
#  '1310.eml',
#  '1311.eml',
#  '1312.eml',
#  '1313.eml',
#  '1314.eml',
#  '1315.eml',
#  '1316.eml',
#  '1317.eml',
#  '1318.eml',
#  '1319.eml',
#  '132.eml',
#  '1320.eml',
#  '1321.eml',
#  '1322.eml',
#  '1323.eml',
#  '1324.eml',
#  '1325.eml',
#  '1326.eml',
#  '1327.eml',
#  '1328.eml',
#  '1329.eml',
#  '133.eml',
#  '1330.eml',
#  '1331.eml',
#  '1332.eml',
#  '1333.eml',
#  '1334.eml',
#  '1335.eml',
#  '1336.eml',
#  '1337.eml',
#  '1338.eml',
#  '1339.eml',
#  '134.eml',
#  '1340.eml',
#  '1341.eml',
#  '1342.eml',
#  '1343.eml',
#  '1344.eml',
#  '1345.eml',
#  '1346.eml',
#  '1347.eml',
#  '1348.eml',
#  '1349.eml',
#  '135.eml',
#  '1350.eml',
#  '1351.eml',
#  '1352.eml',
#  '1353.eml',
#  '1354.eml',
#  '1355.eml',
#  '1356.eml',
#  '1357.eml',
#  '1358.eml',
#  '1359.eml',
#  '136.eml',
#  '1360.eml',
#  '1361.eml',
#  '1362.eml',
#  '1363.eml',
#  '1364.eml',
#  '1365.eml',
#  '1366.eml',
#  '1367.eml',
#  '1368.eml',
#  '1369.eml',
#  '137.eml',
#  '1370.eml',
#  '1371.eml',
#  '1372.eml',
#  '1373.eml',
#  '1374.eml',
#  '1375.eml',
#  '1376.eml',
#  '1377.eml',
#  '1378.eml',
#  '1379.eml',
#  '138.eml',
#  '1380.eml',
#  '1381.eml',
#  '1382.eml',
#  '1383.eml',
#  '1384.eml',
#  '1385.eml',
#  '1386.eml',
#  '1387.eml',
#  '1388.eml',
#  '1389.eml',
#  '139.eml',
#  '1390.eml',
#  '1391.eml',
#  '1392.eml',
#  '1393.eml',
#  '1394.eml',
#  '1395.eml',
#  '1396.eml',
#  '1397.eml',
#  '1398.eml',
#  '1399.eml',
#  '14.eml',
#  '140.eml',
#  '1400.eml',
#  '1401.eml',
#  '1402.eml',
#  '1403.eml',
#  '1404.eml',
#  '1405.eml',
#  '1406.eml',
#  '1407.eml',
#  '1408.eml',
#  '1409.eml',
#  '141.eml',
#  '1410.eml',
#  '1411.eml',
#  '1412.eml',
#  '1413.eml',
#  '1414.eml',
#  '1415.eml',
#  '1416.eml',
#  '1417.eml',
#  '1418.eml',
#  '1419.eml',
#  '142.eml',
#  '1420.eml',
#  '1421.eml',
#  '1422.eml',
#  '1423.eml',
#  '1424.eml',
#  '1425.eml',
#  '1426.eml',
#  '1427.eml',
#  '1428.eml',
#  '1429.eml',
#  '143.eml',
#  '1430.eml',
#  '1431.eml',
#  '1432.eml',
#  '1433.eml',
#  '1434.eml',
#  '1435.eml',
#  '1436.eml',
#  '1437.eml',
#  '1438.eml',
#  '1439.eml',
#  '144.eml',
#  '1440.eml',
#  '1441.eml',
#  '1442.eml',
#  '1443.eml',
#  '1444.eml',
#  '1445.eml',
#  '1446.eml',
#  '1447.eml',
#  '1448.eml',
#  '1449.eml',
#  '145.eml',
#  '1450.eml',
#  '1451.eml',
#  '1452.eml',
#  '1453.eml',
#  '1454.eml',
#  '1456.eml',
#  '1457.eml',
#  '1458.eml',
#  '1459.eml',
#  '146.eml',
#  '1460.eml',
#  '1461.eml',
#  '1462.eml',
#  '1463.eml',
#  '1464.eml',
#  '1465.eml',
#  '1466.eml',
#  '1467.eml',
#  '1468.eml',
#  '1469.eml',
#  '147.eml',
#  '1470.eml',
#  '1471.eml',
#  '1472.eml',
#  '1473.eml',
#  '1474.eml',
#  '1475.eml',
#  '1476.eml',
#  '1477.eml',
#  '1478.eml',
#  '1479.eml',
#  '1480.eml',
#  '1481.eml',
#  '1482.eml',
#  '1483.eml',
#  '1484.eml',
#  '1485.eml',
#  '1486.eml',
#  '1487.eml',
#  '1488.eml',
#  '1489.eml',
#  '1490.eml',
#  '1491.eml',
#  '1492.eml',
#  '1493.eml',
#  '1494.eml',
#  '1495.eml',
#  '1496.eml',
#  '1497.eml',
#  '1498.eml',
#  '1499.eml',
#  '150.eml',
#  '1500.eml',
#  '1501.eml',
#  '1502.eml',
#  '1503.eml',
#  '1504.eml',
#  '1505.eml',
#  '1506.eml',
#  '1507.eml',
#  '1508.eml',
#  '1509.eml',
#  '1510.eml',
#  '1511.eml',
#  '1512.eml',
#  '1513.eml',
#  '1514.eml',
#  '1515.eml',
#  '1516.eml',
#  '1517.eml',
#  '1518.eml',
#  '1519.eml',
#  '152.eml',
#  '1520.eml',
#  '1521.eml',
#  '1522.eml',
#  '1523.eml',
#  '1524.eml',
#  '1525.eml',
#  '1526.eml',
#  '1527.eml',
#  '1528.eml',
#  '1529.eml',
#  '153.eml',
#  '1530.eml',
#  '1531.eml',
#  '1532.eml',
#  '1533.eml',
#  '1534.eml',
#  '1535.eml',
#  '1536.eml',
#  '1537.eml',
#  '1538.eml',
#  '1539.eml',
#  '154.eml',
#  '1540.eml',
#  '1541.eml',
#  '1542.eml',
#  '1543.eml',
#  '1544.eml',
#  '1545.eml',
#  '1546.eml',
#  '1547.eml',
#  '1548.eml',
#  '1549.eml',
#  '155.eml',
#  '1550.eml',
#  '1551.eml',
#  '1552.eml',
#  '1553.eml',
#  '1554.eml',
#  '1555.eml',
#  '1556.eml',
#  '1557.eml',
#  '1558.eml',
#  '1559.eml',
#  '156.eml',
#  '1560.eml',
#  '1561.eml',
#  '1562.eml',
#  '1563.eml',
#  '1564.eml',
#  '1565.eml',
#  '1566.eml',
#  '1567.eml',
#  '1568.eml',
#  '1569.eml',
#  '157.eml',
#  '1570.eml',
#  '1571.eml',
#  '1572.eml',
#  '1573.eml',
#  '1574.eml',
#  '1575.eml',
#  '1576.eml',
#  '1577.eml',
#  '1578.eml',
#  '1579.eml',
#  '158.eml',
#  '1580.eml',
#  '1581.eml',
#  '1582.eml',
#  '1583.eml',
#  '1584.eml',
#  '1585.eml',
#  '1586.eml',
#  '1587.eml',
#  '1588.eml',
#  '1589.eml',
#  '159.eml',
#  '1590.eml',
#  '1591.eml',
#  '1592.eml',
#  '1593.eml',
#  '1594.eml',
#  '1595.eml',
#  '1596.eml',
#  '1597.eml',
#  '1598.eml',
#  '1599.eml',
#  '16.eml',
#  '160.eml',
#  '1600.eml',
#  '1601.eml',
#  '1602.eml',
#  '1603.eml',
#  '1604.eml',
#  '1605.eml',
#  '1606.eml',
#  '1607.eml',
#  '1608.eml',
#  '1609.eml',
#  '161.eml',
#  '1610.eml',
#  '1611.eml',
#  '1612.eml',
#  '1613.eml',
#  '1614.eml',
#  '1615.eml',
#  '1616.eml',
#  '1617.eml',
#  '1618.eml',
#  '1619.eml',
#  '162.eml',
#  '1620.eml',
#  '1621.eml',
#  '1622.eml',
#  '1623.eml',
#  '1624.eml',
#  '1625.eml',
#  '1626.eml',
#  '1627.eml',
#  '1628.eml',
#  '1629.eml',
#  '163.eml',
#  '1630.eml',
#  '1631.eml',
#  '1632.eml',
#  '1633.eml',
#  '1634.eml',
#  '1635.eml',
#  '1636.eml',
#  '1637.eml',
#  '1638.eml',
#  '1639.eml',
#  '164.eml',
#  '1640.eml',
#  '1641.eml',
#  '1642.eml',
#  '1643.eml',
#  '1644.eml',
#  '1645.eml',
#  '1646.eml',
#  '1647.eml',
#  '1648.eml',
#  '1649.eml',
#  '165.eml',
#  '1650.eml',
#  '1651.eml',
#  '1652.eml',
#  '1653.eml',
#  '1654.eml',
#  '1655.eml',
#  '1656.eml',
#  '1657.eml',
#  '1658.eml',
#  '1659.eml',
#  '166.eml',
#  '1660.eml',
#  '1661.eml',
#  '1662.eml',
#  '1663.eml',
#  '1664.eml',
#  '1665.eml',
#  '1666.eml',
#  '1667.eml',
#  '1668.eml',
#  '1669.eml',
#  '167.eml',
#  '1670.eml',
#  '1671.eml',
#  '1672.eml',
#  '1673.eml',
#  '1674.eml',
#  '1675.eml',
#  '1676.eml',
#  '1677.eml',
#  '1678.eml',
#  '1679.eml',
#  '168.eml',
#  '1680.eml',
#  '1681.eml',
#  '1682.eml',
#  '1683.eml',
#  '1684.eml',
#  '1685.eml',
#  '1686.eml',
#  '1687.eml',
#  '1688.eml',
#  '1689.eml',
#  '169.eml',
#  '1690.eml',
#  '1691.eml',
#  '1692.eml',
#  '1693.eml',
#  '1694.eml',
#  '1695.eml',
#  '1696.eml',
#  '1697.eml',
#  '1698.eml',
#  '1699.eml',
#  '17.eml',
#  '1700.eml',
#  '1701.eml',
#  '1702.eml',
#  '1703.eml',
#  '1704.eml',
#  '1705.eml',
#  '1706.eml',
#  '1707.eml',
#  '1708.eml',
#  '1709.eml',
#  '1710.eml',
#  '1711.eml',
#  '1712.eml',
#  '1713.eml',
#  '1714.eml',
#  '1715.eml',
#  '1716.eml',
#  '1717.eml',
#  '1718.eml',
#  '1719.eml',
#  '172.eml',
#  '1720.eml',
#  '1721.eml',
#  '1722.eml',
#  '1723.eml',
#  '1724.eml',
#  '1725.eml',
#  '1726.eml',
#  '1727.eml',
#  '1728.eml',
#  '1729.eml',
#  '173.eml',
#  '1730.eml',
#  '1731.eml',
#  '1732.eml',
#  '1733.eml',
#  '1734.eml',
#  '1735.eml',
#  '1736.eml',
#  '1737.eml',
#  '1738.eml',
#  '1739.eml',
#  '174.eml',
#  '1740.eml',
#  '1741.eml',
#  '1742.eml',
#  '1743.eml',
#  '1744.eml',
#  '1745.eml',
#  '1746.eml',
#  '1747.eml',
#  '1748.eml',
#  '1749.eml',
#  '175.eml',
#  '1750.eml',
#  '1751.eml',
#  '1752.eml',
#  '1753.eml',
#  '1754.eml',
#  '1755.eml',
#  '1756.eml',
#  '1757.eml',
#  '1758.eml',
#  '1759.eml',
#  '176.eml',
#  '1760.eml',
#  '1761.eml',
#  '1762.eml',
#  '1763.eml',
#  '1764.eml',
#  '1765.eml',
#  '1766.eml',
#  '1767.eml',
#  '1768.eml',
#  '1769.eml',
#  '177.eml',
#  '1770.eml',
#  '1771.eml',
#  '1772.eml',
#  '1773.eml',
#  '1774.eml',
#  '1775.eml',
#  '1776.eml',
#  '1777.eml',
#  '1778.eml',
#  '1779.eml',
#  '178.eml',
#  '1780.eml',
#  '1781.eml',
#  '1782.eml',
#  '1783.eml',
#  '1784.eml',
#  '1785.eml',
#  '1786.eml',
#  '1787.eml',
#  '1788.eml',
#  '1789.eml',
#  '179.eml',
#  '1790.eml',
#  '1791.eml',
#  '1792.eml',
#  '1793.eml',
#  '1794.eml',
#  '1795.eml',
#  '1796.eml',
#  '1797.eml',
#  '1798.eml',
#  '1799.eml',
#  '18.eml',
#  '180.eml',
#  '1800.eml',
#  '1801.eml',
#  '1802.eml',
#  '1803.eml',
#  '1804.eml',
#  '1805.eml',
#  '1806.eml',
#  '1807.eml',
#  '1808.eml',
#  '1809.eml',
#  '181.eml',
#  '1810.eml',
#  '1811.eml',
#  '1812.eml',
#  '1813.eml',
#  '1814.eml',
#  '1815.eml',
#  '1816.eml',
#  '1817.eml',
#  '1818.eml',
#  '1819.eml',
#  '1820.eml',
#  '1821.eml',
#  '1822.eml',
#  '1823.eml',
#  '1824.eml',
#  '1825.eml',
#  '1826.eml',
#  '1827.eml',
#  '1828.eml',
#  '1829.eml',
#  '183.eml',
#  '1830.eml',
#  '1831.eml',
#  '1832.eml',
#  '1833.eml',
#  '1834.eml',
#  '1835.eml',
#  '1836.eml',
#  '1837.eml',
#  '1838.eml',
#  '1839.eml',
#  '184.eml',
#  '1840.eml',
#  '1841.eml',
#  '1842.eml',
#  '1843.eml',
#  '1844.eml',
#  '1845.eml',
#  '1846.eml',
#  '1847.eml',
#  '1848.eml',
#  '1849.eml',
#  '185.eml',
#  '1850.eml',
#  '1851.eml',
#  '1852.eml',
#  '1853.eml',
#  '1854.eml',
#  '1855.eml',
#  '1856.eml',
#  '1857.eml',
#  '1858.eml',
#  '1859.eml',
#  '186.eml',
#  '1860.eml',
#  '1861.eml',
#  '1862.eml',
#  '1863.eml',
#  '1864.eml',
#  '1865.eml',
#  '1866.eml',
#  '1867.eml',
#  '1868.eml',
#  '1869.eml',
#  '187.eml',
#  '1870.eml',
#  '1871.eml',
#  '1872.eml',
#  '1873.eml',
#  '1874.eml',
#  '1875.eml',
#  '1876.eml',
#  '1877.eml',
#  '1878.eml',
#  '1879.eml',
#  '188.eml',
#  '1880.eml',
#  '1881.eml',
#  '1882.eml',
#  '1883.eml',
#  '1884.eml',
#  '1885.eml',
#  '1888.eml',
#  '1889.eml',
#  '189.eml',
#  '1890.eml',
#  '1892.eml',
#  '1893.eml',
#  '1894.eml',
#  '1895.eml',
#  '1896.eml',
#  '1897.eml',
#  '1898.eml',
#  '1899.eml',
#  '19.eml',
#  '190.eml',
#  '1900.eml',
#  '1901.eml',
#  '1902.eml',
#  '1903.eml',
#  '1904.eml',
#  '1905.eml',
#  '1906.eml',
#  '1908.eml',
#  '1909.eml',
#  '191.eml',
#  '1910.eml',
#  '1911.eml',
#  '1912.eml',
#  '1913.eml',
#  '1914.eml',
#  ...]

# %%
import bs4
import xml.etree.ElementTree as ET
import re

# as per recommendation from @freylis, compile once only
CLEANR = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
pattern = re.compile(r'"https?://[^ ]*"')


def cleanhtml(raw_html):
  cleantext = re.sub(CLEANR, '', raw_html)
  return cleantext
def remove_tags(text):
    
    return ''.join(ET.fromstring(text).itertext())

def listToString(s):
    # initialize an empty string
    str1 = ""
    # traverse in the string
    for ele in s:
        str1 += ele
        if s.index(ele)<len(s)-1:
            str1 += ','
        
    # return string
    return str1

url_list=[]
body_list=[]
from_list=[]
to_list=[]
subject_list=[]
date_list=[]
other_url_list=[]
for text in dir_list:
    f = open(r"phishingMails/"+text, "r",errors="ignore")
    print(f.name,"da")

    c=extract(f,f.name)
    #get_body
    html = c["html"]
    soup = bs4.BeautifulSoup(html)
    aTags = soup.find_all("body")
    if str(aTags)!= "[]" :
        aTags=str(aTags[0])
        body=cleanhtml(aTags)
        body=body.replace("\\n","")
        body=body.replace("\\t","")
        body=body.replace("\xa0","")
    #get_url
    html = c["html"]
    soup = bs4.BeautifulSoup(html)
    aTags = soup.find_all("a")
    aTags
    urls = [tag['href'] for tag in aTags if 'href' in tag.attrs ]
    k=[]
    for i in aTags:
        k.append(cleanhtml(str(i)))
    
    other_url=[]    
    other_url=re.findall(pattern, html)
    
    
    date_list.append(c["date"])
    from_list.append(c["from"])
    to_list.append(c["to"])
    subject_list.append(c["subject"])
    url=listToString(k)

    url_list.append(url)
    body_list.append(body)
    other_url_list.append(listToString(other_url)) 

    
    f.close()
# Out:
# phishingMails/1.eml da
#
# phishingMails/10.eml da
#
# phishingMails/100.eml da
#
# phishingMails/1000.eml da
#
# phishingMails/1001.eml da
#
# phishingMails/1002.eml da
#
# phishingMails/1003.eml da
#
# phishingMails/1004.eml da
#
# phishingMails/1005.eml da
#
# phishingMails/1006.eml da
#
# phishingMails/1007.eml da
#
# phishingMails/1008.eml da
#
# phishingMails/1009.eml da
#
# phishingMails/101.eml da
#
# phishingMails/1010.eml da
#
# phishingMails/1011.eml da
#
# phishingMails/1012.eml da
#
# phishingMails/1013.eml da
#
# phishingMails/1014.eml da
#
# phishingMails/1015.eml da
#
# phishingMails/1016.eml da
#
# phishingMails/1017.eml da
#
# phishingMails/1018.eml da
#
# phishingMails/1019.eml da
#
# phishingMails/102.eml da
#
# phishingMails/1020.eml da
#
# phishingMails/1021.eml da
#
# phishingMails/1022.eml da
#
# phishingMails/1023.eml da
#
# phishingMails/1024.eml da
#
# phishingMails/1025.eml da
#
# phishingMails/1026.eml da
#
# phishingMails/1027.eml da
#
# phishingMails/1028.eml da
#
# phishingMails/1029.eml da
#
# phishingMails/103.eml da
#
# phishingMails/1030.eml da
#
# phishingMails/1031.eml da
#
# phishingMails/1032.eml da
#
# phishingMails/1033.eml da
#
#
# phishingMails/1034.eml da
#
# phishingMails/1035.eml da
#
# phishingMails/1036.eml da
#
# phishingMails/1037.eml da
#
# phishingMails/1038.eml da
#
# phishingMails/1039.eml da
#
# phishingMails/104.eml da
#
# phishingMails/1040.eml da
#
# phishingMails/1041.eml da
#
# phishingMails/1042.eml da
#
# phishingMails/1043.eml da
#
# phishingMails/1044.eml da
#
# phishingMails/1045.eml da
#
# phishingMails/1046.eml da
#
# phishingMails/1047.eml da
#
# phishingMails/1048.eml da
#
# phishingMails/1049.eml da
#
# phishingMails/105.eml da
#
# phishingMails/1050.eml da
#
# phishingMails/1051.eml da
#
# phishingMails/1052.eml da
#
# phishingMails/1053.eml da
#
# phishingMails/1054.eml da
#
# phishingMails/1055.eml da
#
# phishingMails/1056.eml da
#
# phishingMails/1057.eml da
#
# phishingMails/1058.eml da
#
# phishingMails/1059.eml da
#
# phishingMails/106.eml da
#
# phishingMails/1060.eml da
#
# phishingMails/1061.eml da
#
# phishingMails/1062.eml da
#
# phishingMails/1063.eml da
#
# phishingMails/1064.eml da
#
# phishingMails/1065.eml da
#
# phishingMails/1066.eml da
#
# phishingMails/1067.eml da
#
# phishingMails/1068.eml da
#
# phishingMails/1069.eml da
#
# phishingMails/107.eml da
#
# phishingMails/1070.eml da
#
# phishingMails/1071.eml da
#
# phishingMails/1072.eml da
#
# phishingMails/1073.eml da
#
# phishingMails/1074.eml da
#
# phishingMails/1075.eml da
#
# phishingMails/1076.eml da
#
# phishingMails/1077.eml da
#
# phishingMails/1078.eml da
#
# phishingMails/1079.eml da
#
# phishingMails/108.eml da
#
# phishingMails/1080.eml da
#
# phishingMails/1081.eml da
#
# phishingMails/1082.eml da
#
# phishingMails/1083.eml da
#
# phishingMails/1084.eml da
#
# phishingMails/1085.eml da
#
# phishingMails/1086.eml da
#
# phishingMails/1087.eml da
#
# phishingMails/1088.eml da
#
# phishingMails/1089.eml da
#
# phishingMails/109.eml da
#
# phishingMails/1090.eml da
#
# phishingMails/1091.eml da
#
# phishingMails/1092.eml da
#
# phishingMails/1093.eml da
#
# phishingMails/1094.eml da
#
# phishingMails/1095.eml da
#
# phishingMails/1096.eml da
#
# phishingMails/1097.eml da
#
# phishingMails/1098.eml da
#
# phishingMails/1099.eml da
#
# phishingMails/11.eml da
#
# phishingMails/110.eml da
#
# phishingMails/1100.eml da
#
#
# phishingMails/1101.eml da
#
# phishingMails/1102.eml da
#
#
# phishingMails/1103.eml da
#
# phishingMails/1104.eml da
#
# phishingMails/1105.eml da
#
# phishingMails/1106.eml da
#
# phishingMails/1107.eml da
#
# phishingMails/1108.eml da
#
# phishingMails/1109.eml da
#
# phishingMails/111.eml da
#
# phishingMails/1110.eml da
#
# phishingMails/1111.eml da
#
# phishingMails/1112.eml da
#
#
# phishingMails/1113.eml da
#
# phishingMails/1114.eml da
#
#
# phishingMails/1115.eml da
#
# phishingMails/1116.eml da
#
# phishingMails/1117.eml da
#
# phishingMails/1118.eml da
#
# phishingMails/1119.eml da
#
# phishingMails/112.eml da
#
# phishingMails/1120.eml da
#
# phishingMails/1121.eml da
#
# phishingMails/1122.eml da
#
# phishingMails/1123.eml da
#
# phishingMails/1124.eml da
#
# phishingMails/1125.eml da
#
# phishingMails/1126.eml da
#
# phishingMails/1127.eml da
#
# phishingMails/1128.eml da
#
# phishingMails/1129.eml da
#
# phishingMails/113.eml da
#
# phishingMails/1130.eml da
#
# phishingMails/1131.eml da
#
# phishingMails/1132.eml da
#
# phishingMails/1133.eml da
#
# phishingMails/1134.eml da
#
# phishingMails/1135.eml da
#
# phishingMails/1136.eml da
#
# phishingMails/1137.eml da
#
# phishingMails/1138.eml da
#
# phishingMails/1139.eml da
#
#
# phishingMails/114.eml da
#
# phishingMails/1140.eml da
#
# phishingMails/1141.eml da
#
# phishingMails/1142.eml da
#
# phishingMails/1143.eml da
#
# phishingMails/1144.eml da
#
# phishingMails/1145.eml da
#
# phishingMails/1146.eml da
#
# phishingMails/1147.eml da
#
# phishingMails/1148.eml da
#
#
# phishingMails/1149.eml da
#
#
# phishingMails/115.eml da
#
# phishingMails/1150.eml da
#
# phishingMails/1151.eml da
#
# phishingMails/1152.eml da
#
# phishingMails/1153.eml da
#
# phishingMails/1154.eml da
#
# phishingMails/1155.eml da
#
# phishingMails/1156.eml da
#
# phishingMails/1157.eml da
#
# phishingMails/1158.eml da
#
# phishingMails/1159.eml da
#
# phishingMails/116.eml da
#
# phishingMails/1160.eml da
#
# phishingMails/1161.eml da
#
# phishingMails/1162.eml da
#
#
# phishingMails/1163.eml da
#
#
# phishingMails/1164.eml da
#
# phishingMails/1165.eml da
#
# phishingMails/1166.eml da
#
# phishingMails/1167.eml da
#
# phishingMails/1168.eml da
#
# phishingMails/1169.eml da
#
# phishingMails/117.eml da
#
# phishingMails/1170.eml da
#
# phishingMails/1171.eml da
#
# phishingMails/1172.eml da
#
# phishingMails/1173.eml da
#
# phishingMails/1174.eml da
#
# phishingMails/1175.eml da
#
# phishingMails/1176.eml da
#
# phishingMails/1177.eml da
#
# phishingMails/1178.eml da
#
# phishingMails/1179.eml da
#
# phishingMails/118.eml da
#
# phishingMails/1180.eml da
#
# phishingMails/1181.eml da
#
# phishingMails/1182.eml da
#
# phishingMails/1183.eml da
#
# phishingMails/1184.eml da
#
# phishingMails/1185.eml da
#
# phishingMails/1186.eml da
#
# phishingMails/1187.eml da
#
# phishingMails/1188.eml da
#
# phishingMails/1189.eml da
#
# phishingMails/119.eml da
#
# phishingMails/1190.eml da
#
# phishingMails/1191.eml da
#
# phishingMails/1192.eml da
#
# phishingMails/1193.eml da
#
# phishingMails/1194.eml da
#
# phishingMails/1195.eml da
#
# phishingMails/1196.eml da
#
# phishingMails/1197.eml da
#
# phishingMails/1198.eml da
#
# phishingMails/1199.eml da
#
# phishingMails/12.eml da
#
# phishingMails/120.eml da
#
# phishingMails/1200.eml da
#
# phishingMails/1201.eml da
#
# phishingMails/1202.eml da
#
# phishingMails/1203.eml da
#
# phishingMails/1204.eml da
#
# phishingMails/1205.eml da
#
# phishingMails/1206.eml da
#
# phishingMails/1207.eml da
#
# phishingMails/1208.eml da
#
# phishingMails/1209.eml da
#
# phishingMails/121.eml da
#
# phishingMails/1210.eml da
#
# phishingMails/1211.eml da
#
# phishingMails/1212.eml da
#
# phishingMails/1213.eml da
#
# phishingMails/1214.eml da
#
# phishingMails/1215.eml da
#
# phishingMails/1216.eml da
#
# phishingMails/1217.eml da
#
# phishingMails/1218.eml da
#
# phishingMails/1219.eml da
#
# phishingMails/122.eml da
#
# phishingMails/1220.eml da
#
# phishingMails/1221.eml da
#
# phishingMails/1222.eml da
#
# phishingMails/1223.eml da
#
# phishingMails/1224.eml da
#
# phishingMails/1225.eml da
#
# phishingMails/1226.eml da
#
# phishingMails/1227.eml da
#
# phishingMails/1228.eml da
#
# phishingMails/1229.eml da
#
# phishingMails/123.eml da
#
# phishingMails/1230.eml da
#
# phishingMails/1231.eml da
#
# phishingMails/1232.eml da
#
# phishingMails/1233.eml da
#
# phishingMails/1234.eml da
#
# phishingMails/1235.eml da
#
# phishingMails/1236.eml da
#
# phishingMails/1237.eml da
#
# phishingMails/1238.eml da
#
# phishingMails/1239.eml da
#
# phishingMails/124.eml da
#
# phishingMails/1240.eml da
#
# phishingMails/1241.eml da
#
# phishingMails/1242.eml da
#
# phishingMails/1243.eml da
#
# phishingMails/1244.eml da
#
# phishingMails/1245.eml da
#
# phishingMails/1246.eml da
#
# phishingMails/1247.eml da
#
#
# phishingMails/1248.eml da
#
#
# phishingMails/1249.eml da
#
# phishingMails/125.eml da
#
# phishingMails/1250.eml da
#
# phishingMails/1252.eml da
#
# phishingMails/1254.eml da
#
# phishingMails/1255.eml da
#
# phishingMails/1256.eml da
#
# phishingMails/1257.eml da
#
# phishingMails/1258.eml da
#
# phishingMails/1259.eml da
#
# phishingMails/126.eml da
#
# phishingMails/1262.eml da
#
# phishingMails/1263.eml da
#
# phishingMails/1264.eml da
#
# phishingMails/1265.eml da
#
# phishingMails/1266.eml da
#
# phishingMails/1267.eml da
#
# phishingMails/1268.eml da
#
# phishingMails/1269.eml da
#
# phishingMails/127.eml da
#
# phishingMails/1270.eml da
#
# phishingMails/1271.eml da
#
# phishingMails/1272.eml da
#
# phishingMails/1273.eml da
#
# phishingMails/1274.eml da
#
# phishingMails/1275.eml da
#
# phishingMails/1276.eml da
#
# phishingMails/1277.eml da
#
# phishingMails/1278.eml da
#
# phishingMails/1279.eml da
#
# phishingMails/128.eml da
#
# phishingMails/1280.eml da
#
# phishingMails/1281.eml da
#
# phishingMails/1282.eml da
# phishingMails/1283.eml da
#
# phishingMails/1284.eml da
#
# phishingMails/1285.eml da
#
# phishingMails/1286.eml da
#
# phishingMails/1287.eml da
#
# phishingMails/1288.eml da
#
# phishingMails/1289.eml da
#
# phishingMails/1290.eml da
#
# phishingMails/1291.eml da
#
# phishingMails/1292.eml da
#
# phishingMails/1293.eml da
#
# phishingMails/1294.eml da
#
# phishingMails/1295.eml da
#
# phishingMails/1296.eml da
#
# phishingMails/1297.eml da
#
# phishingMails/1298.eml da
#
# phishingMails/1299.eml da
#
# phishingMails/13.eml da
#
# phishingMails/1300.eml da
#
#
# phishingMails/1301.eml da
#
# phishingMails/1302.eml da
#
# phishingMails/1303.eml da
#
# phishingMails/1304.eml da
#
# phishingMails/1305.eml da
#
# phishingMails/1306.eml da
#
# phishingMails/1307.eml da
#
# phishingMails/1308.eml da
#
# phishingMails/1309.eml da
#
# phishingMails/131.eml da
#
# phishingMails/1310.eml da
#
# phishingMails/1311.eml da
#
# phishingMails/1312.eml da
#
# phishingMails/1313.eml da
#
# phishingMails/1314.eml da
#
# phishingMails/1315.eml da
#
# phishingMails/1316.eml da
#
# phishingMails/1317.eml da
#
# phishingMails/1318.eml da
#
# phishingMails/1319.eml da
#
# phishingMails/132.eml da
#
# phishingMails/1320.eml da
#
# phishingMails/1321.eml da
#
# phishingMails/1322.eml da
#
# phishingMails/1323.eml da
#
# phishingMails/1324.eml da
#
# phishingMails/1325.eml da
#
# phishingMails/1326.eml da
#
# phishingMails/1327.eml da
#
# phishingMails/1328.eml da
#
# phishingMails/1329.eml da
#
# phishingMails/133.eml da
#
# phishingMails/1330.eml da
#
#
# phishingMails/1331.eml da
#
# phishingMails/1332.eml da
#
# phishingMails/1333.eml da
#
# phishingMails/1334.eml da
#
# phishingMails/1335.eml da
#
# phishingMails/1336.eml da
#
# phishingMails/1337.eml da
#
# phishingMails/1338.eml da
#
# phishingMails/1339.eml da
#
# phishingMails/134.eml da
#
# phishingMails/1340.eml da
#
# phishingMails/1341.eml da
#
# phishingMails/1342.eml da
#
# phishingMails/1343.eml da
#
# phishingMails/1344.eml da
#
# phishingMails/1345.eml da
#
# phishingMails/1346.eml da
#
# phishingMails/1347.eml da
#
# phishingMails/1348.eml da
#
# phishingMails/1349.eml da
#
# phishingMails/135.eml da
#
# phishingMails/1350.eml da
#
# phishingMails/1351.eml da
#
# phishingMails/1352.eml da
#
# phishingMails/1353.eml da
#
# phishingMails/1354.eml da
#
# phishingMails/1355.eml da
#
# phishingMails/1356.eml da
#
# phishingMails/1357.eml da
#
# phishingMails/1358.eml da
#
# phishingMails/1359.eml da
#
# phishingMails/136.eml da
#
# phishingMails/1360.eml da
#
# phishingMails/1361.eml da
#
# phishingMails/1362.eml da
#
# phishingMails/1363.eml da
#
# phishingMails/1364.eml da
#
# phishingMails/1365.eml da
#
# phishingMails/1366.eml da
#
# phishingMails/1367.eml da
#
# phishingMails/1368.eml da
#
# phishingMails/1369.eml da
#
# phishingMails/137.eml da
#
# phishingMails/1370.eml da
#
# phishingMails/1371.eml da
#
# phishingMails/1372.eml da
#
# phishingMails/1373.eml da
#
# phishingMails/1374.eml da
#
# phishingMails/1375.eml da
#
# phishingMails/1376.eml da
#
# phishingMails/1377.eml da
#
# phishingMails/1378.eml da
#
# phishingMails/1379.eml da
#
# phishingMails/138.eml da
#
# phishingMails/1380.eml da
#
# phishingMails/1381.eml da
#
# phishingMails/1382.eml da
#
# phishingMails/1383.eml da
#
# phishingMails/1384.eml da
#
# phishingMails/1385.eml da
#
# phishingMails/1386.eml da
#
# phishingMails/1387.eml da
#
# phishingMails/1388.eml da
#
# phishingMails/1389.eml da
#
# phishingMails/139.eml da
#
# phishingMails/1390.eml da
#
# phishingMails/1391.eml da
#
# phishingMails/1392.eml da
#
# phishingMails/1393.eml da
#
# phishingMails/1394.eml da
#
# phishingMails/1395.eml da
#
# phishingMails/1396.eml da
#
# phishingMails/1397.eml da
#
# phishingMails/1398.eml da
#
# phishingMails/1399.eml da
#
# phishingMails/14.eml da
#
# phishingMails/140.eml da
#
# phishingMails/1400.eml da
#
# phishingMails/1401.eml da
#
# phishingMails/1402.eml da
#
# phishingMails/1403.eml da
#
# phishingMails/1404.eml da
#
# phishingMails/1405.eml da
#
# phishingMails/1406.eml da
#
# phishingMails/1407.eml da
#
# phishingMails/1408.eml da
#
# phishingMails/1409.eml da
#
# phishingMails/141.eml da
#
# phishingMails/1410.eml da
#
# phishingMails/1411.eml da
#
# phishingMails/1412.eml da
#
# phishingMails/1413.eml da
#
# phishingMails/1414.eml da
#
# phishingMails/1415.eml da
#
# phishingMails/1416.eml da
#
# phishingMails/1417.eml da
#
# phishingMails/1418.eml da
#
# phishingMails/1419.eml da
#
# phishingMails/142.eml da
#
# phishingMails/1420.eml da
#
# phishingMails/1421.eml da
#
# phishingMails/1422.eml da
#
# phishingMails/1423.eml da
#
# phishingMails/1424.eml da
#
# phishingMails/1425.eml da
#
# phishingMails/1426.eml da
#
# phishingMails/1427.eml da
#
# phishingMails/1428.eml da
#
# phishingMails/1429.eml da
#
# phishingMails/143.eml da
#
# phishingMails/1430.eml da
#
# phishingMails/1431.eml da
#
# phishingMails/1432.eml da
#
# phishingMails/1433.eml da
#
# phishingMails/1434.eml da
#
# phishingMails/1435.eml da
#
# phishingMails/1436.eml da
#
# phishingMails/1437.eml da
#
# phishingMails/1438.eml da
#
# phishingMails/1439.eml da
#
# phishingMails/144.eml da
#
# phishingMails/1440.eml da
#
# phishingMails/1441.eml da
#
# phishingMails/1442.eml da
#
# phishingMails/1443.eml da
#
# phishingMails/1444.eml da
#
# phishingMails/1445.eml da
# C:\Users\Haboubi\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# phishingMails/1446.eml da
#
# phishingMails/1447.eml da
#
# phishingMails/1448.eml da
#
# phishingMails/1449.eml da
#
# phishingMails/145.eml da
#
# phishingMails/1450.eml da
#
# phishingMails/1451.eml da
#
# phishingMails/1452.eml da
#
# phishingMails/1453.eml da
#
# phishingMails/1454.eml da
#
# phishingMails/1456.eml da
#
# phishingMails/1457.eml da
#
# phishingMails/1458.eml da
#
# phishingMails/1459.eml da
#
# phishingMails/146.eml da
#
# phishingMails/1460.eml da
#
# phishingMails/1461.eml da
#
# phishingMails/1462.eml da
#
# phishingMails/1463.eml da
#
# phishingMails/1464.eml da
#
# phishingMails/1465.eml da
#
# phishingMails/1466.eml da
#
# phishingMails/1467.eml da
#
#
# phishingMails/1468.eml da
#
# phishingMails/1469.eml da
#
# phishingMails/147.eml da
#
# phishingMails/1470.eml da
#
# phishingMails/1471.eml da
#
# phishingMails/1472.eml da
#
# phishingMails/1473.eml da
#
# phishingMails/1474.eml da
#
# phishingMails/1475.eml da
#
# phishingMails/1476.eml da
#
# phishingMails/1477.eml da
#
# phishingMails/1478.eml da
#
# phishingMails/1479.eml da
#
# phishingMails/1480.eml da
#
# phishingMails/1481.eml da
#
# phishingMails/1482.eml da
#
# phishingMails/1483.eml da
#
# phishingMails/1484.eml da
#
# phishingMails/1485.eml da
#
# phishingMails/1486.eml da
#
# phishingMails/1487.eml da
#
# phishingMails/1488.eml da
#
# phishingMails/1489.eml da
#
# phishingMails/1490.eml da
#
# phishingMails/1491.eml da
#
# phishingMails/1492.eml da
#
# phishingMails/1493.eml da
#
# phishingMails/1494.eml da
#
# phishingMails/1495.eml da
#
# phishingMails/1496.eml da
#
# phishingMails/1497.eml da
#
# phishingMails/1498.eml da
#
# phishingMails/1499.eml da
#
# phishingMails/150.eml da
#
# phishingMails/1500.eml da
#
# phishingMails/1501.eml da
#
# phishingMails/1502.eml da
#
# phishingMails/1503.eml da
#
# phishingMails/1504.eml da
#
# phishingMails/1505.eml da
#
# phishingMails/1506.eml da
#
# phishingMails/1507.eml da
#
# phishingMails/1508.eml da
#
# phishingMails/1509.eml da
#
# phishingMails/1510.eml da
#
#
# phishingMails/1511.eml da
#
# phishingMails/1512.eml da
#
# phishingMails/1513.eml da
#
# phishingMails/1514.eml da
#
# phishingMails/1515.eml da
#
# phishingMails/1516.eml da
#
# phishingMails/1517.eml da
#
# phishingMails/1518.eml da
#
# phishingMails/1519.eml da
#
# phishingMails/152.eml da
#
# phishingMails/1520.eml da
#
# phishingMails/1521.eml da
#
# phishingMails/1522.eml da
#
# phishingMails/1523.eml da
#
# phishingMails/1524.eml da
#
# phishingMails/1525.eml da
#
# phishingMails/1526.eml da
#
# phishingMails/1527.eml da
#
# phishingMails/1528.eml da
#
# phishingMails/1529.eml da
#
# phishingMails/153.eml da
#
# phishingMails/1530.eml da
#
# phishingMails/1531.eml da
#
# phishingMails/1532.eml da
#
# phishingMails/1533.eml da
#
# phishingMails/1534.eml da
#
# phishingMails/1535.eml da
#
# phishingMails/1536.eml da
#
# phishingMails/1537.eml da
#
# phishingMails/1538.eml da
#
# phishingMails/1539.eml da
#
# phishingMails/154.eml da
#
# phishingMails/1540.eml da
#
# phishingMails/1541.eml da
#
# phishingMails/1542.eml da
#
# phishingMails/1543.eml da
#
# phishingMails/1544.eml da
#
# phishingMails/1545.eml da
#
# phishingMails/1546.eml da
#
# phishingMails/1547.eml da
#
# phishingMails/1548.eml da
#
# phishingMails/1549.eml da
#
# phishingMails/155.eml da
#
# phishingMails/1550.eml da
#
# phishingMails/1551.eml da
#
# phishingMails/1552.eml da
#
# phishingMails/1553.eml da
#
# phishingMails/1554.eml da
#
# phishingMails/1555.eml da
#
# phishingMails/1556.eml da
#
# phishingMails/1557.eml da
#
# phishingMails/1558.eml da
#
# phishingMails/1559.eml da
#
# phishingMails/156.eml da
#
# phishingMails/1560.eml da
#
# phishingMails/1561.eml da
#
# phishingMails/1562.eml da
#
# phishingMails/1563.eml da
#
# phishingMails/1564.eml da
#
# phishingMails/1565.eml da
#
# phishingMails/1566.eml da
#
# phishingMails/1567.eml da
#
# phishingMails/1568.eml da
#
# phishingMails/1569.eml da
#
# phishingMails/157.eml da
#
# phishingMails/1570.eml da
#
# phishingMails/1571.eml da
#
#
# phishingMails/1572.eml da
#
# phishingMails/1573.eml da
#
# phishingMails/1574.eml da
#
# phishingMails/1575.eml da
#
# phishingMails/1576.eml da
#
# phishingMails/1577.eml da
#
# phishingMails/1578.eml da
#
# phishingMails/1579.eml da
#
# phishingMails/158.eml da
#
# phishingMails/1580.eml da
#
# phishingMails/1581.eml da
#
# phishingMails/1582.eml da
#
# phishingMails/1583.eml da
#
# phishingMails/1584.eml da
#
# phishingMails/1585.eml da
#
# phishingMails/1586.eml da
#
# phishingMails/1587.eml da
#
# phishingMails/1588.eml da
#
# phishingMails/1589.eml da
#
# phishingMails/159.eml da
#
# phishingMails/1590.eml da
#
# phishingMails/1591.eml da
#
# phishingMails/1592.eml da
#
# phishingMails/1593.eml da
#
# phishingMails/1594.eml da
#
# phishingMails/1595.eml da
#
#
# phishingMails/1596.eml da
#
# phishingMails/1597.eml da
#
# phishingMails/1598.eml da
#
# phishingMails/1599.eml da
#
# phishingMails/16.eml da
#
# phishingMails/160.eml da
#
# phishingMails/1600.eml da
#
# phishingMails/1601.eml da
#
# phishingMails/1602.eml da
#
# phishingMails/1603.eml da
#
# phishingMails/1604.eml da
#
# phishingMails/1605.eml da
#
# phishingMails/1606.eml da
#
# phishingMails/1607.eml da
#
# phishingMails/1608.eml da
#
# phishingMails/1609.eml da
#
# phishingMails/161.eml da
#
#
# phishingMails/1610.eml da
#
# phishingMails/1611.eml da
#
# phishingMails/1612.eml da
#
# phishingMails/1613.eml da
#
# phishingMails/1614.eml da
#
# phishingMails/1615.eml da
#
# phishingMails/1616.eml da
#
# phishingMails/1617.eml da
#
# phishingMails/1618.eml da
#
# phishingMails/1619.eml da
#
# phishingMails/162.eml da
#
# phishingMails/1620.eml da
#
# phishingMails/1621.eml da
#
# phishingMails/1622.eml da
#
# phishingMails/1623.eml da
#
# phishingMails/1624.eml da
#
# phishingMails/1625.eml da
#
# phishingMails/1626.eml da
#
# phishingMails/1627.eml da
#
# phishingMails/1628.eml da
#
# phishingMails/1629.eml da
#
# phishingMails/163.eml da
#
#
# phishingMails/1630.eml da
#
# phishingMails/1631.eml da
#
# phishingMails/1632.eml da
#
# phishingMails/1633.eml da
#
# phishingMails/1634.eml da
#
# phishingMails/1635.eml da
#
# phishingMails/1636.eml da
#
# phishingMails/1637.eml da
#
# phishingMails/1638.eml da
#
# phishingMails/1639.eml da
#
# phishingMails/164.eml da
#
# phishingMails/1640.eml da
#
# phishingMails/1641.eml da
#
# phishingMails/1642.eml da
#
# phishingMails/1643.eml da
#
# phishingMails/1644.eml da
#
# phishingMails/1645.eml da
#
# phishingMails/1646.eml da
#
# phishingMails/1647.eml da
#
# phishingMails/1648.eml da
#
# phishingMails/1649.eml da
#
# phishingMails/165.eml da
#
# phishingMails/1650.eml da
#
# phishingMails/1651.eml da
#
# phishingMails/1652.eml da
#
# phishingMails/1653.eml da
#
# phishingMails/1654.eml da
#
#
# phishingMails/1655.eml da
#
# phishingMails/1656.eml da
#
# phishingMails/1657.eml da
#
# phishingMails/1658.eml da
#
# phishingMails/1659.eml da
#
# phishingMails/166.eml da
#
# phishingMails/1660.eml da
#
# phishingMails/1661.eml da
#
# phishingMails/1662.eml da
#
# phishingMails/1663.eml da
#
# phishingMails/1664.eml da
#
# phishingMails/1665.eml da
#
# phishingMails/1666.eml da
#
# phishingMails/1667.eml da
#
# phishingMails/1668.eml da
#
# phishingMails/1669.eml da
#
# phishingMails/167.eml da
#
# phishingMails/1670.eml da
#
# phishingMails/1671.eml da
#
# phishingMails/1672.eml da
#
# phishingMails/1673.eml da
#
# phishingMails/1674.eml da
#
# phishingMails/1675.eml da
#
# phishingMails/1676.eml da
#
# phishingMails/1677.eml da
#
# phishingMails/1678.eml da
#
# phishingMails/1679.eml da
#
# phishingMails/168.eml da
#
# phishingMails/1680.eml da
#
# phishingMails/1681.eml da
#
# phishingMails/1682.eml da
#
# phishingMails/1683.eml da
#
# phishingMails/1684.eml da
#
# phishingMails/1685.eml da
#
# phishingMails/1686.eml da
#
# phishingMails/1687.eml da
#
# phishingMails/1688.eml da
#
# phishingMails/1689.eml da
#
# phishingMails/169.eml da
#
#
# phishingMails/1690.eml da
#
# phishingMails/1691.eml da
#
# phishingMails/1692.eml da
#
# phishingMails/1693.eml da
#
# phishingMails/1694.eml da
#
# phishingMails/1695.eml da
#
# phishingMails/1696.eml da
#
# phishingMails/1697.eml da
#
# phishingMails/1698.eml da
#
# phishingMails/1699.eml da
#
# phishingMails/17.eml da
#
# phishingMails/1700.eml da
#
# phishingMails/1701.eml da
#
# phishingMails/1702.eml da
#
# phishingMails/1703.eml da
#
# phishingMails/1704.eml da
#
# phishingMails/1705.eml da
#
# phishingMails/1706.eml da
#
# phishingMails/1707.eml da
#
# phishingMails/1708.eml da
#
# phishingMails/1709.eml da
#
# phishingMails/1710.eml da
#
# phishingMails/1711.eml da
#
# phishingMails/1712.eml da
#
# phishingMails/1713.eml da
#
# phishingMails/1714.eml da
#
# phishingMails/1715.eml da
#
# phishingMails/1716.eml da
#
# phishingMails/1717.eml da
#
# phishingMails/1718.eml da
#
# phishingMails/1719.eml da
#
# phishingMails/172.eml da
#
# phishingMails/1720.eml da
#
# phishingMails/1721.eml da
#
# phishingMails/1722.eml da
#
# phishingMails/1723.eml da
#
# phishingMails/1724.eml da
#
# phishingMails/1725.eml da
#
# phishingMails/1726.eml da
#
# phishingMails/1727.eml da
# phishingMails/1728.eml da
#
# phishingMails/1729.eml da
#
# phishingMails/173.eml da
#
# phishingMails/1730.eml da
#
# phishingMails/1731.eml da
#
# phishingMails/1732.eml da
#
# phishingMails/1733.eml da
#
# phishingMails/1734.eml da
#
# phishingMails/1735.eml da
#
# phishingMails/1736.eml da
#
# phishingMails/1737.eml da
#
# phishingMails/1738.eml da
#
# phishingMails/1739.eml da
#
# phishingMails/174.eml da
#
# phishingMails/1740.eml da
#
# phishingMails/1741.eml da
#
# phishingMails/1742.eml da
#
# phishingMails/1743.eml da
#
# phishingMails/1744.eml da
#
# phishingMails/1745.eml da
#
# phishingMails/1746.eml da
#
# phishingMails/1747.eml da
#
# phishingMails/1748.eml da
#
# phishingMails/1749.eml da
#
# phishingMails/175.eml da
#
# phishingMails/1750.eml da
#
# phishingMails/1751.eml da
#
# phishingMails/1752.eml da
#
# phishingMails/1753.eml da
#
# phishingMails/1754.eml da
#
# phishingMails/1755.eml da
#
# phishingMails/1756.eml da
#
# phishingMails/1757.eml da
#
# phishingMails/1758.eml da
#
# phishingMails/1759.eml da
#
# phishingMails/176.eml da
#
# phishingMails/1760.eml da
#
# phishingMails/1761.eml da
#
# phishingMails/1762.eml da
#
# phishingMails/1763.eml da
#
# phishingMails/1764.eml da
#
# phishingMails/1765.eml da
#
#
# phishingMails/1766.eml da
#
# phishingMails/1767.eml da
#
# phishingMails/1768.eml da
#
# phishingMails/1769.eml da
#
# phishingMails/177.eml da
#
# phishingMails/1770.eml da
#
# phishingMails/1771.eml da
#
# phishingMails/1772.eml da
#
# phishingMails/1773.eml da
#
# phishingMails/1774.eml da
#
# phishingMails/1775.eml da
#
#
# phishingMails/1776.eml da
#
# phishingMails/1777.eml da
#
# phishingMails/1778.eml da
#
# phishingMails/1779.eml da
#
# phishingMails/178.eml da
#
# phishingMails/1780.eml da
#
# phishingMails/1781.eml da
#
# phishingMails/1782.eml da
#
# phishingMails/1783.eml da
#
# phishingMails/1784.eml da
#
# phishingMails/1785.eml da
#
# phishingMails/1786.eml da
#
# phishingMails/1787.eml da
#
# phishingMails/1788.eml da
#
# phishingMails/1789.eml da
#
# phishingMails/179.eml da
#
# phishingMails/1790.eml da
#
# phishingMails/1791.eml da
#
# phishingMails/1792.eml da
#
# phishingMails/1793.eml da
#
# phishingMails/1794.eml da
#
# phishingMails/1795.eml da
#
# phishingMails/1796.eml da
#
# phishingMails/1797.eml da
#
# phishingMails/1798.eml da
#
# phishingMails/1799.eml da
#
# phishingMails/18.eml da
#
# phishingMails/180.eml da
#
# phishingMails/1800.eml da
#
# phishingMails/1801.eml da
#
# phishingMails/1802.eml da
#
# phishingMails/1803.eml da
#
# phishingMails/1804.eml da
#
# phishingMails/1805.eml da
#
# phishingMails/1806.eml da
#
# phishingMails/1807.eml da
#
# phishingMails/1808.eml da
#
# phishingMails/1809.eml da
#
#
# phishingMails/181.eml da
#
# phishingMails/1810.eml da
#
#
# phishingMails/1811.eml da
#
# phishingMails/1812.eml da
#
#
# phishingMails/1813.eml da
#
# phishingMails/1814.eml da
#
#
# phishingMails/1815.eml da
#
# phishingMails/1816.eml da
#
# phishingMails/1817.eml da
#
# phishingMails/1818.eml da
#
# phishingMails/1819.eml da
#
#
# phishingMails/1820.eml da
#
# phishingMails/1821.eml da
#
# phishingMails/1822.eml da
#
# phishingMails/1823.eml da
#
# phishingMails/1824.eml da
#
# phishingMails/1825.eml da
#
# phishingMails/1826.eml da
#
# phishingMails/1827.eml da
#
#
# phishingMails/1828.eml da
#
#
# phishingMails/1829.eml da
#
# phishingMails/183.eml da
#
#
# phishingMails/1830.eml da
#
# phishingMails/1831.eml da
#
# phishingMails/1832.eml da
#
# phishingMails/1833.eml da
#
# phishingMails/1834.eml da
#
# phishingMails/1835.eml da
#
# phishingMails/1836.eml da
#
#
# phishingMails/1837.eml da
#
# phishingMails/1838.eml da
#
#
# phishingMails/1839.eml da
#
# phishingMails/184.eml da
#
#
# phishingMails/1840.eml da
#
# phishingMails/1841.eml da
#
# phishingMails/1842.eml da
#
# phishingMails/1843.eml da
#
# phishingMails/1844.eml da
#
# phishingMails/1845.eml da
#
# phishingMails/1846.eml da
#
# phishingMails/1847.eml da
#
# phishingMails/1848.eml da
#
# phishingMails/1849.eml da
#
# phishingMails/185.eml da
#
# phishingMails/1850.eml da
#
# phishingMails/1851.eml da
#
# phishingMails/1852.eml da
#
# phishingMails/1853.eml da
#
#
# phishingMails/1854.eml da
#
# phishingMails/1855.eml da
#
# phishingMails/1856.eml da
#
# phishingMails/1857.eml da
#
#
# phishingMails/1858.eml da
#
# phishingMails/1859.eml da
#
# phishingMails/186.eml da
#
# phishingMails/1860.eml da
#
# phishingMails/1861.eml da
#
# phishingMails/1862.eml da
#
# phishingMails/1863.eml da
#
# phishingMails/1864.eml da
#
# phishingMails/1865.eml da
#
# phishingMails/1866.eml da
#
# phishingMails/1867.eml da
#
# phishingMails/1868.eml da
#
#
# phishingMails/1869.eml da
#
# phishingMails/187.eml da
#
# phishingMails/1870.eml da
#
# phishingMails/1871.eml da
#
#
# phishingMails/1872.eml da
#
# phishingMails/1873.eml da
#
# phishingMails/1874.eml da
#
# phishingMails/1875.eml da
#
# phishingMails/1876.eml da
#
# phishingMails/1877.eml da
#
# phishingMails/1878.eml da
#
# phishingMails/1879.eml da
#
# phishingMails/188.eml da
#
#
# phishingMails/1880.eml da
#
#
# phishingMails/1881.eml da
#
# phishingMails/1882.eml da
#
# phishingMails/1883.eml da
#
# phishingMails/1884.eml da
#
# phishingMails/1885.eml da
#
# phishingMails/1888.eml da
#
# phishingMails/1889.eml da
#
# phishingMails/189.eml da
#
# phishingMails/1890.eml da
#
# phishingMails/1892.eml da
#
# phishingMails/1893.eml da
#
#
# phishingMails/1894.eml da
#
#
# phishingMails/1895.eml da
#
#
# phishingMails/1896.eml da
#
#
# phishingMails/1897.eml da
#
# phishingMails/1898.eml da
#
# phishingMails/1899.eml da
#
# phishingMails/19.eml da
#
# phishingMails/190.eml da
#
# phishingMails/1900.eml da
#
# phishingMails/1901.eml da
#
# phishingMails/1902.eml da
#
# phishingMails/1903.eml da
#
# phishingMails/1904.eml da
#
# phishingMails/1905.eml da
#
# phishingMails/1906.eml da
#
# phishingMails/1908.eml da
#
# phishingMails/1909.eml da
#
# phishingMails/191.eml da
#
#
# phishingMails/1910.eml da
#
# phishingMails/1911.eml da
#
# phishingMails/1912.eml da
#
# phishingMails/1913.eml da
#
# phishingMails/1914.eml da
#
# phishingMails/1915.eml da
#
#
# phishingMails/1916.eml da
#
# phishingMails/1917.eml da
#
# phishingMails/1918.eml da
#
# phishingMails/1919.eml da
#
# phishingMails/192.eml da
#
# phishingMails/1920.eml da
#
# phishingMails/1921.eml da
#
# phishingMails/1922.eml da
#
# phishingMails/1923.eml da
#
# phishingMails/1924.eml da
#
# phishingMails/1925.eml da
#
# phishingMails/1926.eml da
#
# phishingMails/1927.eml da
#
# phishingMails/1928.eml da
#
# phishingMails/1929.eml da
#
# phishingMails/193.eml da
#
# phishingMails/1930.eml da
#
# phishingMails/1931.eml da
#
# phishingMails/1932.eml da
#
#
# phishingMails/1933.eml da
#
#
# phishingMails/1934.eml da
#
# phishingMails/1935.eml da
#
# phishingMails/1936.eml da
#
# phishingMails/1937.eml da
#
# phishingMails/1938.eml da
#
# phishingMails/1939.eml da
#
# phishingMails/194.eml da
#
# phishingMails/1940.eml da
#
# phishingMails/1941.eml da
#
# phishingMails/1942.eml da
#
# phishingMails/1943.eml da
#
# phishingMails/1944.eml da
#
# phishingMails/1945.eml da
#
# phishingMails/1946.eml da
#
# phishingMails/1947.eml da
#
# phishingMails/1948.eml da
#
# phishingMails/1949.eml da
#
# phishingMails/195.eml da
#
# phishingMails/1950.eml da
#
# phishingMails/1951.eml da
#
# phishingMails/1952.eml da
#
# phishingMails/1953.eml da
#
# phishingMails/1954.eml da
#
# phishingMails/1955.eml da
#
# phishingMails/1956.eml da
#
# phishingMails/1957.eml da
#
# phishingMails/1958.eml da
#
# phishingMails/1959.eml da
#
# phishingMails/196.eml da
#
# phishingMails/1960.eml da
#
# phishingMails/1961.eml da
#
# phishingMails/1962.eml da
#
# phishingMails/1963.eml da
#
# phishingMails/1964.eml da
#
# phishingMails/1965.eml da
#
# phishingMails/1966.eml da
#
# phishingMails/1967.eml da
#
# phishingMails/1968.eml da
#
# phishingMails/1969.eml da
#
# phishingMails/197.eml da
#
#
# phishingMails/1970.eml da
#
# phishingMails/1971.eml da
#
# phishingMails/1972.eml da
#
# phishingMails/1973.eml da
#
# phishingMails/1974.eml da
#
# phishingMails/1975.eml da
#
# phishingMails/1976.eml da
#
# phishingMails/1977.eml da
#
# phishingMails/1978.eml da
#
# phishingMails/1979.eml da
#
# phishingMails/198.eml da
#
# phishingMails/1980.eml da
#
# phishingMails/1981.eml da
#
# phishingMails/1982.eml da
#
# phishingMails/1983.eml da
#
# phishingMails/1984.eml da
#
# phishingMails/1985.eml da
#
# phishingMails/1986.eml da
#
# phishingMails/1987.eml da
#
# phishingMails/1988.eml da
#
# phishingMails/1989.eml da
#
# phishingMails/1990.eml da
#
# phishingMails/1991.eml da
#
# phishingMails/1992.eml da
#
# phishingMails/1993.eml da
#
# phishingMails/1994.eml da
#
# phishingMails/1995.eml da
#
# phishingMails/1996.eml da
#
# phishingMails/1997.eml da
#
# phishingMails/1998.eml da
#
# phishingMails/1999.eml da
#
# phishingMails/2.eml da
#
# phishingMails/20.eml da
#
# phishingMails/200.eml da
#
#
# phishingMails/2000.eml da
#
# phishingMails/2001.eml da
#
# phishingMails/2002.eml da
#
# phishingMails/2003.eml da
#
# phishingMails/2004.eml da
#
#
# phishingMails/2005.eml da
#
# phishingMails/2006.eml da
# phishingMails/2007.eml da
#
# phishingMails/2008.eml da
#
# phishingMails/2009.eml da
#
# phishingMails/201.eml da
#
# phishingMails/2010.eml da
#
# phishingMails/2011.eml da
#
# phishingMails/2012.eml da
#
# phishingMails/2013.eml da
#
# phishingMails/2014.eml da
#
# phishingMails/2015.eml da
#
# phishingMails/2016.eml da
#
# phishingMails/2017.eml da
#
# phishingMails/2018.eml da
#
# phishingMails/2019.eml da
#
#
# phishingMails/202.eml da
#
# phishingMails/2020.eml da
#
# phishingMails/2021.eml da
#
# phishingMails/2022.eml da
#
# phishingMails/2023.eml da
#
# phishingMails/2024.eml da
#
# phishingMails/2025.eml da
#
# phishingMails/2026.eml da
#
# phishingMails/2027.eml da
#
# phishingMails/2028.eml da
#
# phishingMails/2029.eml da
#
# phishingMails/203.eml da
#
# phishingMails/2030.eml da
#
# phishingMails/2031.eml da
#
# phishingMails/2032.eml da
#
# phishingMails/2033.eml da
#
# phishingMails/2034.eml da
#
# phishingMails/2035.eml da
#
# phishingMails/2036.eml da
#
# phishingMails/2037.eml da
#
# phishingMails/2038.eml da
#
# phishingMails/2039.eml da
#
# phishingMails/204.eml da
#
# phishingMails/2040.eml da
#
# phishingMails/2041.eml da
#
# phishingMails/2042.eml da
#
# phishingMails/2043.eml da
#
# phishingMails/2044.eml da
#
# phishingMails/2045.eml da
#
# phishingMails/2046.eml da
#
# phishingMails/2047.eml da
#
# phishingMails/2048.eml da
#
# phishingMails/2049.eml da
#
# phishingMails/205.eml da
#
# phishingMails/2050.eml da
#
# phishingMails/2051.eml da
#
# phishingMails/2052.eml da
#
# phishingMails/2053.eml da
#
# phishingMails/2054.eml da
#
# phishingMails/2055.eml da
#
# phishingMails/2056.eml da
#
# phishingMails/2057.eml da
#
# phishingMails/2058.eml da
#
# phishingMails/2059.eml da
#
# phishingMails/206.eml da
#
# phishingMails/2060.eml da
#
# phishingMails/2061.eml da
#
#
# phishingMails/2062.eml da
#
#
# phishingMails/2063.eml da
#
# phishingMails/2064.eml da
#
# phishingMails/2065.eml da
#
#
# phishingMails/2066.eml da
#
# phishingMails/2067.eml da
#
# phishingMails/2068.eml da
#
# phishingMails/2069.eml da
#
# phishingMails/207.eml da
#
# phishingMails/2070.eml da
#
# phishingMails/2071.eml da
#
# phishingMails/2072.eml da
#
# phishingMails/2073.eml da
#
# phishingMails/2074.eml da
#
# phishingMails/2075.eml da
#
# phishingMails/2076.eml da
#
# phishingMails/2077.eml da
#
# phishingMails/2078.eml da
#
# phishingMails/2079.eml da
#
# phishingMails/208.eml da
#
# phishingMails/2080.eml da
#
# phishingMails/2081.eml da
#
# phishingMails/2082.eml da
#
# phishingMails/2083.eml da
#
# phishingMails/2084.eml da
#
# phishingMails/2085.eml da
#
# phishingMails/2086.eml da
#
# phishingMails/2087.eml da
#
# phishingMails/2088.eml da
#
# phishingMails/2089.eml da
#
# phishingMails/209.eml da
#
# phishingMails/2090.eml da
#
# phishingMails/2091.eml da
#
# phishingMails/2092.eml da
#
# phishingMails/2093.eml da
#
# phishingMails/2094.eml da
#
# phishingMails/2095.eml da
#
# phishingMails/2096.eml da
#
# phishingMails/2097.eml da
#
# phishingMails/2098.eml da
#
# phishingMails/2099.eml da
#
# phishingMails/21.eml da
#
# phishingMails/210.eml da
#
# phishingMails/2100.eml da
#
# phishingMails/2101.eml da
#
# phishingMails/2102.eml da
#
# phishingMails/2103.eml da
#
# phishingMails/2104.eml da
#
# phishingMails/2105.eml da
#
# phishingMails/2106.eml da
#
# phishingMails/2107.eml da
#
# phishingMails/2108.eml da
#
# phishingMails/2109.eml da
#
# phishingMails/211.eml da
#
# phishingMails/2110.eml da
#
# phishingMails/2111.eml da
#
# phishingMails/2112.eml da
#
# phishingMails/2113.eml da
#
# phishingMails/2114.eml da
#
# phishingMails/2115.eml da
#
# phishingMails/2116.eml da
#
# phishingMails/2117.eml da
#
# phishingMails/2118.eml da
#
# phishingMails/2119.eml da
#
# phishingMails/212.eml da
#
# phishingMails/2120.eml da
#
# phishingMails/2121.eml da
#
# phishingMails/2122.eml da
#
# phishingMails/2123.eml da
#
# phishingMails/2124.eml da
#
# phishingMails/2125.eml da
#
# phishingMails/2126.eml da
#
# phishingMails/2127.eml da
#
# phishingMails/2128.eml da
#
# phishingMails/2129.eml da
#
# phishingMails/2130.eml da
#
# phishingMails/2131.eml da
#
# phishingMails/2132.eml da
#
# phishingMails/2133.eml da
#
# phishingMails/2134.eml da
#
# phishingMails/2135.eml da
#
# phishingMails/2136.eml da
#
# phishingMails/2137.eml da
#
# phishingMails/2138.eml da
#
# phishingMails/2139.eml da
#
# phishingMails/214.eml da
#
# phishingMails/2140.eml da
#
# phishingMails/2141.eml da
#
# phishingMails/2142.eml da
#
# phishingMails/2143.eml da
#
# phishingMails/2144.eml da
#
# phishingMails/2145.eml da
#
# phishingMails/2146.eml da
#
#
# phishingMails/2147.eml da
#
# phishingMails/2148.eml da
#
# phishingMails/2149.eml da
#
# phishingMails/215.eml da
#
# phishingMails/2150.eml da
#
# phishingMails/2151.eml da
#
# phishingMails/2152.eml da
#
# phishingMails/2153.eml da
#
# phishingMails/2154.eml da
#
# phishingMails/2155.eml da
#
# phishingMails/2156.eml da
#
# phishingMails/2157.eml da
#
# phishingMails/2158.eml da
#
# phishingMails/2159.eml da
#
# phishingMails/216.eml da
#
# phishingMails/2160.eml da
#
# phishingMails/2161.eml da
#
# phishingMails/2162.eml da
#
# phishingMails/2163.eml da
#
# phishingMails/2164.eml da
#
# phishingMails/2165.eml da
#
# phishingMails/2166.eml da
#
# phishingMails/2167.eml da
#
# phishingMails/2168.eml da
#
# phishingMails/2169.eml da
#
# phishingMails/2170.eml da
#
# phishingMails/2171.eml da
#
# phishingMails/2172.eml da
#
# phishingMails/2173.eml da
#
#
# phishingMails/2174.eml da
#
# phishingMails/2175.eml da
#
# phishingMails/2176.eml da
#
# phishingMails/2177.eml da
#
# phishingMails/2178.eml da
#
# phishingMails/2179.eml da
#
# phishingMails/218.eml da
#
# phishingMails/2180.eml da
#
# phishingMails/2181.eml da
#
# phishingMails/2182.eml da
#
# phishingMails/2183.eml da
#
# phishingMails/2184.eml da
#
# phishingMails/2185.eml da
#
# phishingMails/2186.eml da
#
# phishingMails/2187.eml da
#
# phishingMails/2188.eml da
#
# phishingMails/2189.eml da
#
# phishingMails/219.eml da
#
# phishingMails/2190.eml da
#
# phishingMails/2191.eml da
#
# phishingMails/2192.eml da
#
# phishingMails/2193.eml da
#
# phishingMails/2194.eml da
#
# phishingMails/2195.eml da
#
# phishingMails/2196.eml da
#
# phishingMails/2197.eml da
#
# phishingMails/2198.eml da
#
# phishingMails/2199.eml da
#
# phishingMails/22.eml da
#
# phishingMails/220.eml da
#
# phishingMails/2200.eml da
#
# phishingMails/2201.eml da
#
# phishingMails/2202.eml da
#
# phishingMails/2203.eml da
#
# phishingMails/2204.eml da
#
# phishingMails/2205.eml da
#
# phishingMails/2206.eml da
#
#
# phishingMails/2207.eml da
#
# phishingMails/2208.eml da
#
# phishingMails/2209.eml da
#
# phishingMails/221.eml da
#
# phishingMails/2210.eml da
#
# phishingMails/2211.eml da
#
# phishingMails/2212.eml da
#
# phishingMails/2213.eml da
#
# phishingMails/2214.eml da
#
# phishingMails/2215.eml da
#
# phishingMails/2216.eml da
#
# phishingMails/2217.eml da
#
# phishingMails/2218.eml da
#
# phishingMails/2219.eml da
#
# phishingMails/222.eml da
#
# phishingMails/2220.eml da
#
# phishingMails/2221.eml da
#
# phishingMails/2222.eml da
#
# phishingMails/2223.eml da
#
# phishingMails/2224.eml da
#
# phishingMails/2225.eml da
#
# phishingMails/2226.eml da
#
# phishingMails/2227.eml da
#
# phishingMails/2228.eml da
#
# phishingMails/2229.eml da
#
# phishingMails/223.eml da
#
#
# phishingMails/2230.eml da
#
# phishingMails/2231.eml da
#
# phishingMails/2232.eml da
#
# phishingMails/2233.eml da
#
# phishingMails/2234.eml da
#
# phishingMails/2235.eml da
#
# phishingMails/2236.eml da
#
# phishingMails/2237.eml da
#
# phishingMails/2238.eml da
#
# phishingMails/2239.eml da
#
# phishingMails/224.eml da
#
# phishingMails/2240.eml da
#
# phishingMails/2241.eml da
#
#
# phishingMails/2242.eml da
#
# phishingMails/2243.eml da
#
# phishingMails/2244.eml da
#
# phishingMails/2245.eml da
#
# phishingMails/2246.eml da
#
# phishingMails/2247.eml da
#
# phishingMails/2248.eml da
#
# phishingMails/2249.eml da
#
# phishingMails/225.eml da
#
# phishingMails/2250.eml da
#
# phishingMails/2251.eml da
#
# phishingMails/2252.eml da
#
# phishingMails/2253.eml da
#
# phishingMails/2254.eml da
#
# phishingMails/2255.eml da
#
# phishingMails/2256.eml da
#
# phishingMails/2257.eml da
#
# phishingMails/2258.eml da
#
# phishingMails/2259.eml da
#
# phishingMails/226.eml da
#
# phishingMails/2260.eml da
#
# phishingMails/2261.eml da
#
# phishingMails/2262.eml da
#
# phishingMails/2263.eml da
#
# phishingMails/2264.eml da
#
# phishingMails/2265.eml da
#
# phishingMails/2266.eml da
#
# phishingMails/2267.eml da
#
# phishingMails/2268.eml da
#
# phishingMails/2269.eml da
#
# phishingMails/227.eml da
#
# phishingMails/2270.eml da
#
# phishingMails/2271.eml da
#
# phishingMails/2272.eml da
#
# phishingMails/2273.eml da
#
# phishingMails/2274.eml da
#
# phishingMails/2275.eml da
#
# phishingMails/2276.eml da
#
# phishingMails/2277.eml da
#
# phishingMails/2278.eml da
#
# phishingMails/228.eml da
#
# phishingMails/229.eml da
#
# phishingMails/23.eml da
#
# phishingMails/230.eml da
#
# phishingMails/231.eml da
#
# phishingMails/232.eml da
#
# phishingMails/233.eml da
#
# phishingMails/235.eml da
#
# phishingMails/236.eml da
#
# phishingMails/237.eml da
#
# phishingMails/238.eml da
#
# phishingMails/239.eml da
#
# phishingMails/24.eml da
#
# phishingMails/240.eml da
#
# phishingMails/241.eml da
#
# phishingMails/242.eml da
# phishingMails/243.eml da
#
# phishingMails/244.eml da
#
# phishingMails/245.eml da
#
# phishingMails/246.eml da
#
# phishingMails/247.eml da
#
# phishingMails/248.eml da
#
# phishingMails/249.eml da
#
# phishingMails/25.eml da
#
# phishingMails/250.eml da
#
# phishingMails/251.eml da
#
# phishingMails/252.eml da
#
# phishingMails/253.eml da
#
# phishingMails/254.eml da
#
# phishingMails/257.eml da
#
# phishingMails/26.eml da
#
# phishingMails/260.eml da
#
# phishingMails/261.eml da
#
# phishingMails/263.eml da
#
# phishingMails/264.eml da
#
# phishingMails/265.eml da
#
# phishingMails/266.eml da
#
# phishingMails/267.eml da
#
# phishingMails/268.eml da
#
# phishingMails/269.eml da
#
# phishingMails/270.eml da
#
# phishingMails/272.eml da
#
# phishingMails/273.eml da
#
# phishingMails/274.eml da
#
# phishingMails/275.eml da
#
# phishingMails/276.eml da
#
# phishingMails/277.eml da
#
# phishingMails/278.eml da
#
# phishingMails/279.eml da
#
# phishingMails/281.eml da
#
# phishingMails/282.eml da
#
# phishingMails/283.eml da
#
# phishingMails/284.eml da
#
# phishingMails/286.eml da
#
# phishingMails/287.eml da
#
#
# phishingMails/288.eml da
#
# phishingMails/289.eml da
#
# phishingMails/29.eml da
#
# phishingMails/290.eml da
#
# phishingMails/291.eml da
#
# phishingMails/292.eml da
#
# phishingMails/293.eml da
#
# phishingMails/295.eml da
#
# phishingMails/296.eml da
#
# phishingMails/297.eml da
#
# phishingMails/298.eml da
#
# phishingMails/299.eml da
#
# phishingMails/3.eml da
#
# phishingMails/30.eml da
#
# phishingMails/300.eml da
#
# phishingMails/301.eml da
#
# phishingMails/302.eml da
#
# phishingMails/303.eml da
#
# phishingMails/304.eml da
#
# phishingMails/305.eml da
#
# phishingMails/306.eml da
#
# phishingMails/307.eml da
#
# phishingMails/308.eml da
#
# phishingMails/309.eml da
#
# phishingMails/31.eml da
#
# phishingMails/310.eml da
#
# phishingMails/311.eml da
#
# phishingMails/312.eml da
#
# phishingMails/313.eml da
#
# phishingMails/314.eml da
#
# phishingMails/315.eml da
#
# phishingMails/316.eml da
#
# phishingMails/317.eml da
#
# phishingMails/318.eml da
#
# phishingMails/319.eml da
#
# phishingMails/32.eml da
#
# phishingMails/320.eml da
#
# phishingMails/321.eml da
#
# phishingMails/322.eml da
#
# phishingMails/323.eml da
#
#
# phishingMails/324.eml da
#
#
# phishingMails/325.eml da
#
#
# phishingMails/326.eml da
#
#
# phishingMails/327.eml da
#
#
# phishingMails/328.eml da
#
#
# phishingMails/329.eml da
#
#
# phishingMails/33.eml da
#
# phishingMails/330.eml da
#
#
# phishingMails/331.eml da
#
#
# phishingMails/332.eml da
#
# phishingMails/333.eml da
#
#
# phishingMails/334.eml da
#
# phishingMails/335.eml da
#
#
# phishingMails/336.eml da
#
#
# phishingMails/337.eml da
#
# phishingMails/338.eml da
#
#
# phishingMails/339.eml da
#
#
# phishingMails/34.eml da
#
# phishingMails/340.eml da
#
#
# phishingMails/341.eml da
#
# phishingMails/342.eml da
#
#
# phishingMails/343.eml da
#
# phishingMails/344.eml da
#
#
# phishingMails/345.eml da
#
#
# phishingMails/346.eml da
#
# phishingMails/347.eml da
#
#
# phishingMails/348.eml da
#
# phishingMails/349.eml da
#
# phishingMails/35.eml da
#
# phishingMails/350.eml da
#
# phishingMails/351.eml da
#
# phishingMails/352.eml da
#
# phishingMails/353.eml da
#
# phishingMails/354.eml da
#
# phishingMails/355.eml da
#
# phishingMails/356.eml da
#
# phishingMails/357.eml da
#
# phishingMails/358.eml da
#
# phishingMails/359.eml da
#
# phishingMails/36.eml da
#
# phishingMails/360.eml da
#
# phishingMails/361.eml da
#
# phishingMails/362.eml da
#
# phishingMails/363.eml da
#
# phishingMails/364.eml da
#
# phishingMails/365.eml da
#
# phishingMails/366.eml da
#
# phishingMails/367.eml da
#
# phishingMails/368.eml da
#
# phishingMails/369.eml da
#
# phishingMails/370.eml da
#
# phishingMails/371.eml da
#
# phishingMails/372.eml da
#
# phishingMails/373.eml da
#
# phishingMails/374.eml da
#
# phishingMails/375.eml da
#
# phishingMails/376.eml da
#
# phishingMails/377.eml da
#
# phishingMails/378.eml da
#
# phishingMails/379.eml da
#
# phishingMails/380.eml da
#
# phishingMails/381.eml da
#
# phishingMails/382.eml da
#
# phishingMails/383.eml da
#
# phishingMails/384.eml da
#
# phishingMails/385.eml da
#
# phishingMails/386.eml da
#
# phishingMails/387.eml da
#
# phishingMails/388.eml da
#
# phishingMails/389.eml da
#
# phishingMails/39.eml da
#
# phishingMails/390.eml da
#
# phishingMails/391.eml da
#
# phishingMails/392.eml da
#
# phishingMails/393.eml da
#
# phishingMails/394.eml da
#
# phishingMails/395.eml da
#
# phishingMails/396.eml da
#
# phishingMails/397.eml da
#
# phishingMails/398.eml da
#
# phishingMails/399.eml da
#
# phishingMails/4.eml da
#
# phishingMails/40.eml da
#
# phishingMails/400.eml da
#
# phishingMails/401.eml da
#
# phishingMails/402.eml da
#
# phishingMails/403.eml da
#
# phishingMails/404.eml da
#
# phishingMails/405.eml da
#
# phishingMails/406.eml da
#
# phishingMails/407.eml da
#
# phishingMails/408.eml da
#
# phishingMails/409.eml da
#
# phishingMails/410.eml da
#
# phishingMails/411.eml da
#
# phishingMails/412.eml da
#
# phishingMails/413.eml da
#
# phishingMails/414.eml da
#
# phishingMails/415.eml da
#
# phishingMails/416.eml da
#
# phishingMails/417.eml da
#
# phishingMails/418.eml da
#
# phishingMails/419.eml da
#
# phishingMails/42.eml da
#
# phishingMails/420.eml da
#
# phishingMails/421.eml da
#
# phishingMails/422.eml da
#
# phishingMails/423.eml da
#
# phishingMails/424.eml da
#
# phishingMails/425.eml da
#
# phishingMails/426.eml da
#
# phishingMails/427.eml da
#
# phishingMails/428.eml da
#
# phishingMails/429.eml da
#
# phishingMails/43.eml da
#
# phishingMails/430.eml da
#
# phishingMails/431.eml da
#
# phishingMails/432.eml da
#
# phishingMails/433.eml da
#
# phishingMails/434.eml da
#
# phishingMails/435.eml da
#
# phishingMails/436.eml da
#
# phishingMails/437.eml da
#
# phishingMails/438.eml da
#
# phishingMails/439.eml da
#
# phishingMails/44.eml da
#
# phishingMails/440.eml da
#
# phishingMails/441.eml da
#
#
# phishingMails/442.eml da
#
# phishingMails/443.eml da
#
# phishingMails/444.eml da
#
# phishingMails/445.eml da
#
# phishingMails/446.eml da
#
# phishingMails/447.eml da
#
# phishingMails/448.eml da
#
# phishingMails/449.eml da
#
# phishingMails/45.eml da
#
# phishingMails/450.eml da
#
# phishingMails/451.eml da
#
# phishingMails/452.eml da
#
# phishingMails/453.eml da
#
# phishingMails/454.eml da
#
# phishingMails/455.eml da
#
#
# phishingMails/456.eml da
#
# phishingMails/457.eml da
#
# phishingMails/458.eml da
#
# phishingMails/459.eml da
#
# phishingMails/46.eml da
#
# phishingMails/460.eml da
#
# phishingMails/461.eml da
#
# phishingMails/462.eml da
#
# phishingMails/463.eml da
#
# phishingMails/464.eml da
#
# phishingMails/465.eml da
#
# phishingMails/466.eml da
#
# phishingMails/467.eml da
#
# phishingMails/468.eml da
#
# phishingMails/469.eml da
#
# phishingMails/47.eml da
#
# phishingMails/470.eml da
#
# phishingMails/471.eml da
#
# phishingMails/472.eml da
#
# phishingMails/473.eml da
#
# phishingMails/474.eml da
#
# phishingMails/475.eml da
#
# phishingMails/476.eml da
#
# phishingMails/477.eml da
#
#
# phishingMails/478.eml da
#
# phishingMails/479.eml da
#
# phishingMails/48.eml da
#
# phishingMails/480.eml da
#
# phishingMails/481.eml da
#
# phishingMails/482.eml da
#
# phishingMails/483.eml da
#
# phishingMails/484.eml da
#
# phishingMails/485.eml da
#
# phishingMails/486.eml da
#
# phishingMails/487.eml da
#
# phishingMails/488.eml da
#
# phishingMails/489.eml da
#
# phishingMails/49.eml da
#
# phishingMails/490.eml da
#
# phishingMails/491.eml da
#
# phishingMails/492.eml da
#
# phishingMails/493.eml da
#
# phishingMails/494.eml da
#
# phishingMails/495.eml da
#
# phishingMails/496.eml da
#
# phishingMails/497.eml da
#
# phishingMails/498.eml da
#
#
# phishingMails/499.eml da
#
# phishingMails/5.eml da
#
# phishingMails/50.eml da
#
# phishingMails/500.eml da
#
# phishingMails/501.eml da
#
# phishingMails/502.eml da
#
# phishingMails/503.eml da
#
# phishingMails/504.eml da
#
# phishingMails/505.eml da
#
# phishingMails/506.eml da
#
# phishingMails/507.eml da
#
# phishingMails/508.eml da
#
# phishingMails/509.eml da
#
# phishingMails/51.eml da
#
# phishingMails/510.eml da
#
# phishingMails/511.eml da
#
# phishingMails/512.eml da
#
# phishingMails/513.eml da
#
# phishingMails/514.eml da
#
# phishingMails/515.eml da
#
# phishingMails/516.eml da
#
# phishingMails/517.eml da
#
# phishingMails/518.eml da
#
# phishingMails/519.eml da
#
# phishingMails/52.eml da
#
# phishingMails/520.eml da
#
# phishingMails/521.eml da
#
# phishingMails/522.eml da
#
# phishingMails/523.eml da
#
# phishingMails/524.eml da
#
# phishingMails/525.eml da
#
# phishingMails/526.eml da
#
# phishingMails/527.eml da
#
# phishingMails/528.eml da
#
# phishingMails/529.eml da
#
# phishingMails/53.eml da
#
# phishingMails/530.eml da
#
# phishingMails/531.eml da
#
# phishingMails/532.eml da
#
# phishingMails/533.eml da
#
# phishingMails/534.eml da
#
# phishingMails/535.eml da
#
# phishingMails/536.eml da
#
# phishingMails/537.eml da
#
# phishingMails/538.eml da
#
# phishingMails/539.eml da
#
# phishingMails/54.eml da
# phishingMails/540.eml da
#
# phishingMails/541.eml da
#
# phishingMails/542.eml da
#
# phishingMails/543.eml da
#
# phishingMails/544.eml da
#
# phishingMails/545.eml da
#
# phishingMails/546.eml da
#
# phishingMails/547.eml da
#
# phishingMails/548.eml da
#
# phishingMails/549.eml da
#
# phishingMails/55.eml da
#
# phishingMails/550.eml da
#
# phishingMails/551.eml da
#
# phishingMails/552.eml da
#
# phishingMails/553.eml da
#
# phishingMails/554.eml da
#
# phishingMails/555.eml da
#
# phishingMails/556.eml da
#
# phishingMails/557.eml da
#
# phishingMails/558.eml da
#
# phishingMails/559.eml da
#
# phishingMails/56.eml da
#
# phishingMails/560.eml da
#
# phishingMails/561.eml da
#
# phishingMails/562.eml da
#
# phishingMails/563.eml da
#
#
# phishingMails/564.eml da
#
# phishingMails/565.eml da
#
# phishingMails/566.eml da
#
# phishingMails/567.eml da
#
# phishingMails/568.eml da
#
# phishingMails/569.eml da
#
# phishingMails/57.eml da
#
# phishingMails/570.eml da
#
# phishingMails/571.eml da
#
# phishingMails/572.eml da
#
# phishingMails/573.eml da
#
# phishingMails/574.eml da
#
# phishingMails/575.eml da
#
# phishingMails/576.eml da
#
# phishingMails/577.eml da
#
# phishingMails/578.eml da
#
# phishingMails/579.eml da
#
# phishingMails/58.eml da
#
# phishingMails/580.eml da
#
# phishingMails/581.eml da
#
# phishingMails/582.eml da
#
# phishingMails/583.eml da
#
# phishingMails/584.eml da
#
# phishingMails/585.eml da
#
# phishingMails/586.eml da
#
# phishingMails/587.eml da
#
# phishingMails/588.eml da
#
# phishingMails/589.eml da
#
# phishingMails/590.eml da
#
# phishingMails/591.eml da
#
# phishingMails/592.eml da
#
# phishingMails/593.eml da
#
# phishingMails/594.eml da
#
# phishingMails/595.eml da
#
# phishingMails/596.eml da
#
# phishingMails/597.eml da
#
# phishingMails/598.eml da
#
# phishingMails/599.eml da
#
# phishingMails/6.eml da
#
# phishingMails/60.eml da
#
# phishingMails/600.eml da
#
# phishingMails/601.eml da
#
# phishingMails/602.eml da
#
# phishingMails/603.eml da
#
# phishingMails/604.eml da
#
# phishingMails/605.eml da
#
# phishingMails/606.eml da
#
# phishingMails/607.eml da
#
# phishingMails/608.eml da
#
# phishingMails/609.eml da
#
# phishingMails/61.eml da
#
# phishingMails/610.eml da
#
# phishingMails/611.eml da
#
# phishingMails/612.eml da
#
# phishingMails/613.eml da
#
# phishingMails/614.eml da
#
# phishingMails/615.eml da
#
# phishingMails/616.eml da
#
# phishingMails/617.eml da
#
# phishingMails/618.eml da
#
# phishingMails/619.eml da
#
# phishingMails/62.eml da
#
# phishingMails/620.eml da
#
# phishingMails/621.eml da
#
# phishingMails/622.eml da
#
# phishingMails/623.eml da
#
# phishingMails/624.eml da
#
# phishingMails/625.eml da
#
# phishingMails/626.eml da
#
# phishingMails/627.eml da
#
# phishingMails/628.eml da
#
# phishingMails/629.eml da
#
# phishingMails/63.eml da
#
# phishingMails/630.eml da
#
#
# phishingMails/631.eml da
#
# phishingMails/632.eml da
#
# phishingMails/633.eml da
#
# phishingMails/634.eml da
#
# phishingMails/635.eml da
#
# phishingMails/636.eml da
#
# phishingMails/637.eml da
#
# phishingMails/638.eml da
#
# phishingMails/639.eml da
#
# phishingMails/64.eml da
#
# phishingMails/640.eml da
#
# phishingMails/641.eml da
#
# phishingMails/642.eml da
#
# phishingMails/643.eml da
#
# phishingMails/644.eml da
#
# phishingMails/645.eml da
#
# phishingMails/646.eml da
#
# phishingMails/647.eml da
#
# phishingMails/648.eml da
#
# phishingMails/649.eml da
#
# phishingMails/65.eml da
#
# phishingMails/650.eml da
#
# phishingMails/651.eml da
#
# phishingMails/652.eml da
#
# phishingMails/653.eml da
#
# phishingMails/654.eml da
#
# phishingMails/655.eml da
#
# phishingMails/656.eml da
#
# phishingMails/657.eml da
#
# phishingMails/658.eml da
#
# phishingMails/659.eml da
#
# phishingMails/66.eml da
#
# phishingMails/660.eml da
#
# phishingMails/661.eml da
#
# phishingMails/662.eml da
#
# phishingMails/663.eml da
#
# phishingMails/664.eml da
#
# phishingMails/665.eml da
#
# phishingMails/666.eml da
#
# phishingMails/667.eml da
#
# phishingMails/668.eml da
#
# phishingMails/669.eml da
#
# phishingMails/67.eml da
#
# phishingMails/670.eml da
#
# phishingMails/671.eml da
#
# phishingMails/672.eml da
#
# phishingMails/673.eml da
#
# phishingMails/674.eml da
#
# phishingMails/675.eml da
#
# phishingMails/676.eml da
#
# phishingMails/677.eml da
#
# phishingMails/678.eml da
#
# phishingMails/679.eml da
#
# phishingMails/68.eml da
#
# phishingMails/680.eml da
#
# phishingMails/681.eml da
#
# phishingMails/682.eml da
#
# phishingMails/683.eml da
#
# phishingMails/684.eml da
#
# phishingMails/685.eml da
#
# phishingMails/686.eml da
#
# phishingMails/687.eml da
#
# phishingMails/688.eml da
#
# phishingMails/689.eml da
#
# phishingMails/69.eml da
#
# phishingMails/690.eml da
#
# phishingMails/691.eml da
#
# phishingMails/692.eml da
#
# phishingMails/693.eml da
#
# phishingMails/694.eml da
#
# phishingMails/695.eml da
#
# phishingMails/696.eml da
#
# phishingMails/697.eml da
#
# phishingMails/698.eml da
#
# phishingMails/699.eml da
#
# phishingMails/7.eml da
#
# phishingMails/70.eml da
#
# phishingMails/700.eml da
#
# phishingMails/701.eml da
#
# phishingMails/702.eml da
#
# phishingMails/703.eml da
#
# phishingMails/704.eml da
#
# phishingMails/705.eml da
#
# phishingMails/706.eml da
#
# phishingMails/707.eml da
#
#
# phishingMails/708.eml da
#
# phishingMails/709.eml da
#
# phishingMails/71.eml da
#
# phishingMails/710.eml da
#
# phishingMails/711.eml da
#
# phishingMails/712.eml da
#
# phishingMails/713.eml da
#
# phishingMails/714.eml da
#
# phishingMails/715.eml da
#
# phishingMails/716.eml da
#
# phishingMails/717.eml da
#
# phishingMails/718.eml da
#
# phishingMails/719.eml da
#
# phishingMails/720.eml da
#
# phishingMails/721.eml da
#
# phishingMails/722.eml da
#
# phishingMails/723.eml da
#
# phishingMails/724.eml da
#
#
# phishingMails/725.eml da
#
# phishingMails/726.eml da
#
# phishingMails/727.eml da
#
# phishingMails/728.eml da
#
# phishingMails/729.eml da
#
# phishingMails/73.eml da
#
# phishingMails/730.eml da
#
# phishingMails/731.eml da
#
# phishingMails/732.eml da
#
# phishingMails/733.eml da
#
#
# phishingMails/734.eml da
#
# phishingMails/735.eml da
#
# phishingMails/736.eml da
#
#
# phishingMails/737.eml da
#
#
# phishingMails/738.eml da
#
#
# phishingMails/739.eml da
#
# phishingMails/74.eml da
#
# phishingMails/740.eml da
#
#
# phishingMails/741.eml da
#
# phishingMails/742.eml da
#
# phishingMails/743.eml da
#
# phishingMails/744.eml da
#
# phishingMails/745.eml da
#
# phishingMails/746.eml da
#
#
# phishingMails/747.eml da
#
# phishingMails/748.eml da
#
# phishingMails/749.eml da
#
# phishingMails/75.eml da
#
# phishingMails/750.eml da
#
# phishingMails/751.eml da
#
# phishingMails/752.eml da
#
# phishingMails/753.eml da
#
# phishingMails/754.eml da
#
# phishingMails/755.eml da
#
# phishingMails/756.eml da
#
# phishingMails/757.eml da
#
# phishingMails/758.eml da
#
# phishingMails/759.eml da
#
#
# phishingMails/76.eml da
#
# phishingMails/760.eml da
#
#
# phishingMails/761.eml da
#
# phishingMails/762.eml da
#
# phishingMails/763.eml da
#
# phishingMails/764.eml da
#
# phishingMails/765.eml da
#
# phishingMails/766.eml da
#
# phishingMails/767.eml da
#
# phishingMails/768.eml da
#
# phishingMails/769.eml da
#
#
# phishingMails/77.eml da
#
# phishingMails/770.eml da
#
# phishingMails/771.eml da
#
# phishingMails/772.eml da
#
#
# phishingMails/773.eml da
#
#
# phishingMails/774.eml da
#
# phishingMails/775.eml da
#
# phishingMails/776.eml da
#
#
# phishingMails/777.eml da
#
# phishingMails/778.eml da
#
# phishingMails/779.eml da
#
# phishingMails/78.eml da
#
# phishingMails/780.eml da
#
#
# phishingMails/781.eml da
#
# phishingMails/782.eml da
#
#
# phishingMails/783.eml da
#
# phishingMails/784.eml da
#
# phishingMails/785.eml da
#
# phishingMails/786.eml da
#
# phishingMails/787.eml da
#
# phishingMails/788.eml da
#
# phishingMails/789.eml da
#
# phishingMails/79.eml da
#
# phishingMails/790.eml da
#
# phishingMails/791.eml da
#
# phishingMails/792.eml da
#
# phishingMails/793.eml da
#
# phishingMails/794.eml da
#
# phishingMails/795.eml da
#
# phishingMails/796.eml da
#
# phishingMails/797.eml da
#
# phishingMails/798.eml da
#
# phishingMails/799.eml da
#
#
# phishingMails/8.eml da
#
# phishingMails/80.eml da
#
# phishingMails/800.eml da
#
# phishingMails/801.eml da
#
# phishingMails/802.eml da
#
# phishingMails/803.eml da
#
# phishingMails/804.eml da
#
# phishingMails/805.eml da
#
# phishingMails/806.eml da
#
# phishingMails/807.eml da
#
# phishingMails/808.eml da
#
# phishingMails/809.eml da
#
# phishingMails/81.eml da
#
# phishingMails/810.eml da
#
# phishingMails/811.eml da
#
# phishingMails/812.eml da
#
# phishingMails/813.eml da
#
# phishingMails/814.eml da
#
# phishingMails/815.eml da
#
# phishingMails/816.eml da
#
# phishingMails/817.eml da
#
# phishingMails/818.eml da
#
# phishingMails/819.eml da
#
# phishingMails/82.eml da
#
# phishingMails/820.eml da
#
# phishingMails/821.eml da
#
# phishingMails/822.eml da
#
# phishingMails/823.eml da
#
# phishingMails/824.eml da
#
# phishingMails/825.eml da
#
# phishingMails/826.eml da
#
# phishingMails/827.eml da
#
# phishingMails/828.eml da
#
# phishingMails/829.eml da
#
# phishingMails/83.eml da
#
# phishingMails/830.eml da
#
# phishingMails/831.eml da
#
#
# phishingMails/832.eml da
#
# phishingMails/833.eml da
#
# phishingMails/834.eml da
#
# phishingMails/835.eml da
#
# phishingMails/836.eml da
#
# phishingMails/837.eml da
#
# phishingMails/838.eml da
#
# phishingMails/839.eml da
#
# phishingMails/84.eml da
#
# phishingMails/840.eml da
#
# phishingMails/841.eml da
#
# phishingMails/842.eml da
#
# phishingMails/843.eml da
#
# phishingMails/844.eml da
# phishingMails/845.eml da
#
# phishingMails/846.eml da
#
# phishingMails/847.eml da
#
#
# phishingMails/848.eml da
#
# phishingMails/849.eml da
#
# phishingMails/85.eml da
#
#
# phishingMails/850.eml da
#
# phishingMails/851.eml da
#
# phishingMails/852.eml da
#
# phishingMails/853.eml da
#
# phishingMails/854.eml da
#
# phishingMails/855.eml da
#
# phishingMails/856.eml da
#
# phishingMails/857.eml da
#
# phishingMails/858.eml da
#
# phishingMails/859.eml da
#
# phishingMails/86.eml da
#
#
# phishingMails/860.eml da
#
# phishingMails/861.eml da
#
# phishingMails/862.eml da
#
# phishingMails/863.eml da
#
# phishingMails/864.eml da
#
# phishingMails/865.eml da
#
# phishingMails/866.eml da
#
# phishingMails/867.eml da
#
# phishingMails/868.eml da
#
# phishingMails/869.eml da
#
# phishingMails/87.eml da
#
# phishingMails/870.eml da
#
# phishingMails/871.eml da
#
# phishingMails/872.eml da
#
# phishingMails/873.eml da
#
# phishingMails/874.eml da
#
#
# phishingMails/875.eml da
#
# phishingMails/876.eml da
#
# phishingMails/877.eml da
#
# phishingMails/878.eml da
#
# phishingMails/879.eml da
#
# phishingMails/88.eml da
#
# phishingMails/880.eml da
#
# phishingMails/881.eml da
#
# phishingMails/882.eml da
#
# phishingMails/883.eml da
#
# phishingMails/884.eml da
#
# phishingMails/885.eml da
#
# phishingMails/886.eml da
#
# phishingMails/887.eml da
#
# phishingMails/888.eml da
#
# phishingMails/889.eml da
#
# phishingMails/89.eml da
#
# phishingMails/890.eml da
#
# phishingMails/891.eml da
#
# phishingMails/892.eml da
#
# phishingMails/893.eml da
#
# phishingMails/894.eml da
#
# phishingMails/895.eml da
#
# phishingMails/896.eml da
#
# phishingMails/897.eml da
#
# phishingMails/898.eml da
#
# phishingMails/899.eml da
#
# phishingMails/90.eml da
#
# phishingMails/900.eml da
#
# phishingMails/901.eml da
#
# phishingMails/902.eml da
#
# phishingMails/903.eml da
#
# phishingMails/904.eml da
#
# phishingMails/905.eml da
#
# phishingMails/906.eml da
#
# phishingMails/907.eml da
#
# phishingMails/908.eml da
#
# phishingMails/909.eml da
#
# phishingMails/91.eml da
#
# phishingMails/910.eml da
#
#
# phishingMails/911.eml da
#
# phishingMails/912.eml da
#
# phishingMails/913.eml da
#
# phishingMails/914.eml da
#
# phishingMails/915.eml da
#
# phishingMails/916.eml da
#
# phishingMails/917.eml da
#
# phishingMails/918.eml da
#
# phishingMails/919.eml da
#
# phishingMails/92.eml da
#
# phishingMails/920.eml da
#
# phishingMails/921.eml da
#
# phishingMails/922.eml da
#
#
# phishingMails/923.eml da
#
# phishingMails/924.eml da
#
# phishingMails/925.eml da
#
# phishingMails/926.eml da
#
# phishingMails/927.eml da
#
#
# phishingMails/928.eml da
#
# phishingMails/929.eml da
#
# phishingMails/93.eml da
#
# phishingMails/930.eml da
#
# phishingMails/931.eml da
#
# phishingMails/932.eml da
#
# phishingMails/933.eml da
#
# phishingMails/934.eml da
#
# phishingMails/935.eml da
#
# phishingMails/936.eml da
#
# phishingMails/937.eml da
#
# phishingMails/938.eml da
#
# phishingMails/939.eml da
#
# phishingMails/94.eml da
#
# phishingMails/940.eml da
#
# phishingMails/941.eml da
#
# phishingMails/942.eml da
#
# phishingMails/943.eml da
#
# phishingMails/944.eml da
#
# phishingMails/945.eml da
#
# phishingMails/946.eml da
#
# phishingMails/947.eml da
#
# phishingMails/948.eml da
#
# phishingMails/949.eml da
#
# phishingMails/95.eml da
#
# phishingMails/950.eml da
#
# phishingMails/951.eml da
#
# phishingMails/952.eml da
#
# phishingMails/953.eml da
#
# phishingMails/954.eml da
#
# phishingMails/955.eml da
#
# phishingMails/956.eml da
#
#
# phishingMails/957.eml da
#
#
# phishingMails/958.eml da
#
# phishingMails/959.eml da
#
# phishingMails/96.eml da
#
# phishingMails/960.eml da
#
# phishingMails/961.eml da
#
# phishingMails/962.eml da
#
# phishingMails/963.eml da
#
# phishingMails/964.eml da
#
# phishingMails/965.eml da
#
# phishingMails/966.eml da
#
#
# phishingMails/967.eml da
#
#
# phishingMails/968.eml da
#
# phishingMails/969.eml da
#
# phishingMails/97.eml da
#
# phishingMails/970.eml da
#
# phishingMails/971.eml da
#
# phishingMails/972.eml da
#
# phishingMails/973.eml da
#
# phishingMails/974.eml da
#
# phishingMails/975.eml da
#
# phishingMails/976.eml da
#
# phishingMails/977.eml da
#
# phishingMails/978.eml da
#
# phishingMails/979.eml da
#
# phishingMails/98.eml da
#
# phishingMails/980.eml da
#
# phishingMails/981.eml da
#
# phishingMails/982.eml da
#
# phishingMails/983.eml da
#
# phishingMails/984.eml da
#
# phishingMails/985.eml da
#
# phishingMails/986.eml da
#
# phishingMails/987.eml da
#
# phishingMails/988.eml da
#
# phishingMails/989.eml da
#
# phishingMails/99.eml da
#
# phishingMails/990.eml da
#
# phishingMails/991.eml da
#
# phishingMails/992.eml da
#
# phishingMails/993.eml da
#
# phishingMails/994.eml da
#
# phishingMails/995.eml da
#
# phishingMails/996.eml da
#
# phishingMails/997.eml da
#
# phishingMails/998.eml da
#
# phishingMails/999.eml da

# %%
import pandas as pd
dic={"date":date_list,"from":from_list,"to":to_list,"subject":subject_list,"body":body_list,"url":url_list,"other_url":other_url_list}
dic=pd.DataFrame(dic)
dic
# Out:
#                                         date  \
# 0            Thu, 30 Oct 2003 08:52:16 +0200
# 1             Fri, 1 Jul 2005 17:57:54 -0700
# 2      Wed, 17 Aug 2005 18:28:02 +0000 (GMT)
# 3     Thu, 21 Sep 2006 04:46:36 +0200 (CEST)
# 4            Thu, 21 Sep 2006 05:52:53 +0200
# ...                                      ...
# 2234   Wed, 20 Sep 2006 05:54:42 -0400 (EDT)
# 2235         Wed, 20 Sep 2006 09:09:24 -0500
# 2236         Wed, 20 Sep 2006 18:44:26 -0100
# 2237         Wed, 20 Sep 2006 14:56:32 -0700
# 2238         Wed, 20 Sep 2006 16:10:14 -0700
#
#                                                    from  \
# 0       "emailconfirm@ebay.com" <emailconfirm@ebay.com>
# 1                   "Ebay Team" <aw45-confirm@ebay.com>
# 2                           PayPal <service@paypal.com>
# 3     service@intl.paypal.com <service@intl.paypal.com>
# 4             "service@paypal.com" <service@paypal.com>
# ...                                                 ...
# 2234  "FIFTH THIRD BANK 2006" <custservice-ref-45811...
# 2235                       "eBay" <aw-confirm@ebay.com>
# 2236        "PayPal service" <security@intl.paypal.com>
# 2237  "Fifth Third Bank, 2006" <operator-393568id@53...
# 2238                 "PayPal Inc." <account@paypal.com>
#
#                              to  \
# 0
# 1     undisclosed-recipients: ;
# 2              user@example.com
# 3              user@example.com
# 4      undisclosed-recipients:;
# ...                         ...
# 2234    user <user@example.com>
# 2235   undisclosed-recipients:;
# 2236           user@example.com
# 2237    user <user@example.com>
# 2238   undisclosed-recipients:;
#
#                                                 subject  \
# 0                            eBay account verification!
# 1                eBay - verify your account information
# 2                Notification of limited account access
# 3      ..PayPal Notification..: Update your information
# 4     We recently noticed one or more attempts to lo...
# ...                                                 ...
# 2234  Customer notification: data confirmation [Tue,...
# 2235  Win the best car Viper SRT-10 offered by eBay.com
# 2236  IMPORTANT : Notification Of Limited Account Ac...
# 2237  Fifth Third Bank customer notification: data c...
# 2238   Notice from PayPal - Identity protection matters
#
#                                                    body  \
# 0     b'Dear eBay User ,After fraud complaints from ...
# 1     b'WelcomeWelcome to a community of sellers tha...
# 2     b' Dear valuedPayPal\xaemember:PayPal\xae is c...
# 3     b'PayPal#message .dummy {}#message, #message T...
# 4     b'We recently noticed one or more attempts to ...
# ...                                                 ...
# 2234  b'"No!     atone       bootleg    ""I am!She w...
# 2235  b'                                            ...
# 2236  b'Dear PayPal Member,During our regularly sche...
# 2237  b'The rules for this part of the game were Ann...
# 2238  b'\nPayPal#xptErrorBox {width: 100%; margin: 0...
#
#                                                     url  \
# 0     http://signin.ebay.com/aw-cgi/eBayISAPI.dll?Si...
# 1
# 2     \n,https://www.paypal.com/cgi-bin/webscr?cmd=_...
# 3     \n        ,Click here to activate your account...
# 4     \n\t\t\t\thttps://www.paypal.com/cgi-bin/websc...
# ...                                                 ...
# 2234                                                 \n
# 2235  \n          ,Click Here,\n      ,Your account\...
# 2236  https://www.paypalcom/cgi-bin/webscr?cmd=_logi...
# 2237                                                 \n
# 2238                                ,,Get Verified!,,,,
#
#                                               other_url
# 0                  "http://hform.com/form.cgi?10081481"
# 1     "http://pics.ebaystatic.com/aw/pics/powerselle...
# 2     "http://www.paypal.com/cgi-bin/webscr?cmd=_hom...
# 3     "https://www.paypal.com/us","http://images.pay...
# 4     "http://www.maes.idv.tw/phpnuke/modules/copper...
# ...                                                 ...
# 2234
# 2235  "http://pages.ebay.com/","http://pics.ebaystat...
# 2236  "http://adsl-072-149-046-139.sip.bct.bellsouth...
# 2237
# 2238  "https://www.paypalobjects.com/en_US/i/scr/pix...
#
# [2239 rows x 7 columns]

# %%
dic['other_url'].iloc[152]
# Out:
# '"http://pics.ebaystatic.com/aw/pics/uk/logos/ebay_95x39.gif","http://pics.ebaystatic.com/aw/pics/globalAssets/ltCurve.gif","http://pics.ebaystatic.com/aw/pics/globalAssets/rtCurve.gif","http://pics.ebaystatic.com/aw/pics/s.gif","http://pics.ebaystatic.com/aw/pics/s.gif","http://pics.ebaystatic.com/aw/pics/s.gif","http://pics.ebaystatic.com/aw/pics/s.gif","http://pics.ebaystatic.com/aw/pics/s.gif","http://pics.ebaystatic.com/aw/pics/s.gif","http://contact-ebay-com-wsebay-isapidl.smtp.ru/SignInco_partnerId_2pUserId_siteid_3pageType_pa1_i1_bshowgif_UsingSSL_ru_pp_pa2_errmsg_runame_ruparams_ruproduct_sid_favoritenav_confirm_ebxPageType_existingEmail_isCheckout_migrateVisitor","http://pics.ebaystatic.com/aw/pics/s.gif","http://contact-ebay-com-wsebay-isapidl.smtp.ru/SignInco_partnerId_2pUserId_siteid_3pageType_pa1_i1_bshowgif_UsingSSL_ru_pp_pa2_errmsg_runame_ruparams_ruproduct_sid_favoritenav_confirm_ebxPageType_existingEmail_isCheckout_migrateVisitor","http://pics.ebaystatic.com/aw/pics/icon/iconShootTeal_25x25.gif","http://pics.ebaystatic.com/aw/pics/s.gif","http://pics.ebaystatic.com/aw/pics/s.gif","http://pics.ebaystatic.com/aw/pics/s.gif","http://pics.ebaystatic.com/aw/pics/s.gif","http://pics.ebaystatic.com/aw/pics/s.gif","http://contact-ebay-com-wsebay-isapidl.smtp.ru/SignInco_partnerId_2pUserId_siteid_3pageType_pa1_i1_bshowgif_UsingSSL_ru_pp_pa2_errmsg_runame_ruparams_ruproduct_sid_favoritenav_confirm_ebxPageType_existingEmail_isCheckout_migrateVisitor","http://pics.ebaystatic.com/aw/pics/s.gif","http://mail.yahoo.com/config/login?/ym/Compose?To=mark1@aol.com","http://pics.ebaystatic.com/aw/pics/s.gif","http://contact-ebay-com-wsebay-isapidl.smtp.ru/SignInco_partnerId_2pUserId_siteid_3pageType_pa1_i1_bshowgif_UsingSSL_ru_pp_pa2_errmsg_runame_ruparams_ruproduct_sid_favoritenav_confirm_ebxPageType_existingEmail_isCheckout_migrateVisitor","http://pics.ebaystatic.com/aw/pics/uk/buttons/btnRespondNow.gif","http://pics.ebaystatic.com/aw/pics/s.gif","http://pics.ebaystatic.com/aw/pics/s.gif","http://contact-ebay-com-wsebay-isapidl.smtp.ru/SignInco_partnerId_2pUserId_siteid_3pageType_pa1_i1_bshowgif_UsingSSL_ru_pp_pa2_errmsg_runame_ruparams_ruproduct_sid_favoritenav_confirm_ebxPageType_existingEmail_isCheckout_migrateVisitor","http://contact-ebay-com-wsebay-isapidl.smtp.ru/SignInco_partnerId_2pUserId_siteid_3pageType_pa1_i1_bshowgif_UsingSSL_ru_pp_pa2_errmsg_runame_ruparams_ruproduct_sid_favoritenav_confirm_ebxPageType_existingEmail_isCheckout_migrateVisitor","http://pics.ebaystatic.com/aw/pics/s.gif","http://pics.ebaystatic.com/aw/pics/securityCenter/imgShield_25x25.gif","http://pics.ebaystatic.com/aw/pics/securityCenter/imgTabCorner_25x25.gif","http://contact-ebay-com-wsebay-isapidl.smtp.ru/SignInco_partnerId_2pUserId_siteid_3pageType_pa1_i1_bshowgif_UsingSSL_ru_pp_pa2_errmsg_runame_ruparams_ruproduct_sid_favoritenav_confirm_ebxPageType_existingEmail_isCheckout_migrateVisitor","http://pics.ebaystatic.com/aw/pics/s.gif","http://pics.ebaystatic.com/aw/pics/s.gif","http://contact-ebay-com-wsebay-isapidl.smtp.ru/SignInco_partnerId_2pUserId_siteid_3pageType_pa1_i1_bshowgif_UsingSSL_ru_pp_pa2_errmsg_runame_ruparams_ruproduct_sid_favoritenav_confirm_ebxPageType_existingEmail_isCheckout_migrateVisitor","http://contact-ebay-com-wsebay-isapidl.smtp.ru/SignInco_partnerId_2pUserId_siteid_3pageType_pa1_i1_bshowgif_UsingSSL_ru_pp_pa2_errmsg_runame_ruparams_ruproduct_sid_favoritenav_confirm_ebxPageType_existingEmail_isCheckout_migrateVisitor","http://pics.ebaystatic.com/aw/pics/s.gif","http://pics.ebaystatic.com/aw/pics/s.gif","http://pics.ebaystatic.com/aw/pics/s.gif","http://pics.ebaystatic.com/aw/pics/s.gif","http://contact-ebay-com-wsebay-isapidl.smtp.ru/SignInco_partnerId_2pUserId_siteid_3pageType_pa1_i1_bshowgif_UsingSSL_ru_pp_pa2_errmsg_runame_ruparams_ruproduct_sid_favoritenav_confirm_ebxPageType_existingEmail_isCheckout_migrateVisitor","http://by23fd.bay23.hotmail.msn.com/cgi-bin/compose?mailto=1&msg=MSG1155292683.3&start=1239629&len= ...

# %%
file_name="first_data.csv"
dic.to_csv(file_name, sep='\t', encoding='utf-8',index=False)

# %%
a=pd.read_csv("first_data.csv",sep='\t')
a.head()
# Out:
#                                      date  \
# 0         Thu, 30 Oct 2003 08:52:16 +0200
# 1          Fri, 1 Jul 2005 17:57:54 -0700
# 2   Wed, 17 Aug 2005 18:28:02 +0000 (GMT)
# 3  Thu, 21 Sep 2006 04:46:36 +0200 (CEST)
# 4         Thu, 21 Sep 2006 05:52:53 +0200
#
#                                                 from  \
# 0    "emailconfirm@ebay.com" <emailconfirm@ebay.com>
# 1                "Ebay Team" <aw45-confirm@ebay.com>
# 2                        PayPal <service@paypal.com>
# 3  service@intl.paypal.com <service@intl.paypal.com>
# 4          "service@paypal.com" <service@paypal.com>
#
#                           to  \
# 0                        NaN
# 1  undisclosed-recipients: ;
# 2           user@example.com
# 3           user@example.com
# 4   undisclosed-recipients:;
#
#                                              subject  \
# 0                         eBay account verification!
# 1             eBay - verify your account information
# 2             Notification of limited account access
# 3   ..PayPal Notification..: Update your information
# 4  We recently noticed one or more attempts to lo...
#
#                                                 body  \
# 0  b'Dear eBay User ,After fraud complaints from ...
# 1  b'WelcomeWelcome to a community of sellers tha...
# 2  b' Dear valuedPayPal\xaemember:PayPal\xae is c...
# 3  b'PayPal#message .dummy {}#message, #message T...
# 4  b'We recently noticed one or more attempts to ...
#
#                                                  url  \
# 0  http://signin.ebay.com/aw-cgi/eBayISAPI.dll?Si...
# 1                                                NaN
# 2  \n,https://www.paypal.com/cgi-bin/webscr?cmd=_...
# 3  \n        ,Click here to activate your account...
# 4  \n\t\t\t\thttps://www.paypal.com/cgi-bin/websc...
#
#                                            other_url
# 0               "http://hform.com/form.cgi?10081481"
# 1  "http://pics.ebaystatic.com/aw/pics/powerselle...
# 2  "http://www.paypal.com/cgi-bin/webscr?cmd=_hom...
# 3  "https://www.paypal.com/us","http://images.pay...
# 4  "http://www.maes.idv.tw/phpnuke/modules/copper...

# %%
a.shape
# Out:
# (2239, 7)
